# %% [markdown]
# # Introduction
#
# In the following notebook, I will be performing an EDA of some Airbnb data in the San Francisco area. This data pertains to the last calendar year, which at the time of this analysis would be December 2018 - December 2019.
#
# In the following analysis, I will be looking to explore the data and answer the following questions:
#
# - Machine learning target variables distributions
# - Growth of Airbnb rental properties by neighborhood in the SF area
# - Average per night rental based upon property type
#
#
# *GitHub Repo References*
# The raw data files can be found [here](https://github.com/KishenSharma6/Airbnb-SF_ML_-_Text_Analysis/tree/master/Data/01_Raw).
#
# The raw data aggregation scripts can be found [here](https://github.com/KishenSharma6/Airbnb-SF_ML_-_Text_Analysis/tree/master/Project%20Codes/01.%20Raw%20Data%20Aggregation%20Scripts).
#
# The data cleaning scripts can be found [here](https://github.com/KishenSharma6/Airbnb-SF_ML_-_Text_Analysis/tree/master/Project%20Codes/02.%20Data%20Cleaning%20Scripts).

# %%
#Read in libraries
import dask.dataframe as dd
import swifter

import pandas as pd
import pandas_profiling

import re

import numpy as np
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Set pandas options
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows',100)
pd.options.display.float_format = '{:.0f}'.format

#Set plot aesthetics
plt.style.use('ggplot')

#Ignore warnings
import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# **Read in Data**

# %%
#Set path to data
path = r'C:\Users\kishe\Documents\Data Science\Projects\Python Projects\In Progress\Air BnB - SF\Data\02_Intermediate/'

#Read listings Data
listings = pd.read_csv(path + '01_04_2020_Listings_Cleaned.csv',index_col=0, low_memory=True, sep=',')

# %% [markdown]
# # Data Preview

# %% [markdown]
# **Airbnb Listings Data**

# %%
#Preview listings data
display(listings.head())
# Out:
#    accommodates                                          amenities  \
# 0             3   TV  Cable TV  Internet Wifi Kitchen  Pets liv...
# 1             5   Internet Wifi Kitchen Heating  Family/kid fri...
# 2             2   TV Internet Wifi Kitchen  Free street parking...
# 3             2   TV Internet Wifi Kitchen  Free street parking...
# 4             5   TV Internet Wifi Kitchen Heating  Family/kid ...
#
#    availability_30  availability_365  bathrooms  bed_type  bedrooms  beds  \
# 0                0                77          1  Real Bed         1     2
# 1                0                 0          1  Real Bed         2     3
# 2               30               365          4  Real Bed         1     1
# 3               30               365          4  Real Bed         1     1
# 4               30                90          2  Real Bed         2     2
#
#    chlc  chlc_private_rooms  chlc_shared_rooms calendar_last_scraped  \
# 0     1                   0                  0            2019-04-03
# 1     1                   0                  0            2019-04-03
# 2     9                   9                  0            2019-04-03
# 3     9                   9                  0            2019-04-03
# 4     2                   0                  0            2019-04-03
#
#   calendar_updated          cancellation_policy           city  cleaning_fee  \
# 0       1 week ago                     moderate  San Francisco           100
# 1     4 months ago  strict_14_with_grace_period  San Francisco           100
# 2    17 months ago  strict_14_with_grace_period  San Francisco            50
# 3    17 months ago  strict_14_with_grace_period  San Francisco            50
# 4     4 months ago  strict_14_with_grace_period  San Francisco           225
#
#                                          description  extra_people  \
# 0  New update: the house next door is under const...            25
# 1  We live in a large Victorian house on a quiet ...             0
# 2  Nice and good public transportation.  7 minute...            12
# 3  Nice and good public transportation.  7 minute...            12
# 4  Pls email before booking.  Interior featured i...           150
#
#   first_review  guests_included  \
# 0   2009-07-23                2
# 1   2009-05-03                2
# 2   2009-08-31                1
# 3   2014-09-08                1
# 4   2009-09-25                2
#
#                                           host_about  host_id  \
# 0  We are a family with 2 boys born in 2009 and 2...     1169
# 1  Philip: English transplant to the Bay Area and...     8904
# 2  7 minutes walk to UCSF.  15 minutes walk to US...    21994
# 3  7 minutes walk to UCSF.  15 minutes walk to US...    21994
# 4  Always searching for a perfect piece at Europe...    24215
#
#    host_identity_verified  host_is_superhost  host_listings_count  \
# 0                    True               True                    1
# 1                    True              False                    2
# 2                    True              False                   10
# 3                    True              False                   10
# 4                    True              False                    2
#
#                               host_location         host_name  \
# 0  San Francisco, California, United States             Holly
# 1  San Francisco, California, United States  Philip And Tania
# 2  San Francisco, California, United States             Aaron
# 3  San Francisco, California, United States             Aaron
# 4  San Francisco, California, United States              Rosy
#
#   host_neighbourhood  host_response_rate  host_response_time  host_since  \
# 0    Duboce Triangle                 100      within an hour  2008-07-31
# 1     Bernal Heights                  80        within a day  2009-03-02
# 2        Cole Valley                 100  within a few hours  2009-06-17
# 3        Cole Valley                 100  within a few hours  2009-06-17
# 4       Alamo Square                 100      within an hour  2009-07-02
#
#                                   host_verifications  \
# 0     email    phone    facebook    reviews    kba
# 1    email    phone    reviews    kba    work_ema...
# 2    email    phone    reviews    jumio    govern...
# 3    email    phone    reviews    jumio    govern...
# 4                 email    phone    reviews    kba
#
#                                          house_rules    id  instant_bookable  \
# 0  * No Pets - even visiting guests for a short t...   958              True
# 1  Please respect the house, the art work, the fu...  5858             False
# 2  No party, No smoking, not for any kinds of smo...  7918             False
# 3       no pet no smoke no party inside the building  8142             False
# 4  House Manual and House Rules will be provided ...  8339             False
#
#    is_location_exact last_review  latitude  longitude         market  \
# 0               True  2019-03-16        38       -122  San Francisco
# 1               True  2017-08-06        38       -122  San Francisco
# 2               True  2016-11-21        38       -122  San Francisco
# 3               True  2018-09-12        38       -122  San Francisco
# 4               True  2018-08-11        38       -122  San Francisco
#
#    maximum_maximum_nights                                               name  \
# 0                      30                Bright, Modern Garden Unit - 1BR/1B
# 1                      60                                 Creative Sanctuary
# 2                      60         A Friendly Room - UCSF/USF - San Francisco
# 3                      90  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                    1125                    Historic Alamo Square Victorian
#
#                                neighborhood_overview neighbourhood_cleansed  \
# 0  *Quiet cul de sac in friendly neighborhood *St...       Western Addition
# 1  I love how our neighborhood feels quiet but is...         Bernal Heights
# 2  Shopping old town, restaurants, McDonald, Whol...         Haight Ashbury
# 3                                                NaN         Haight Ashbury
# 4                                                NaN       Western Addition
#
#    number_of_reviews  number_of_reviews_ltm  price property_type  \
# 0                183                     51    170     Apartment
# 1                111                      0    235     Apartment
# 2                 17                      0     65     Apartment
# 3                  8                      1     65     Apartment
# 4                 27                      1    785         House
#
#    require_guest_phone_verification  require_guest_profile_picture  \
# 0                             False                          False
# 1                             False                          False
# 2                             False                          False
# 3                             False                          False
# 4                              True                           True
#
#    requires_license  review_scores_accuracy  review_scores_checkin  \
# 0              True                      10                     10
# 1              True                      10                     10
# 2              True                       8                      9
# 3              True                       9                     10
# 4              True                      10                     10
#
#    review_scores_cleanliness  review_scores_communication  \
# 0                         10                           10
# 1                         10                           10
# 2                          8                            9
# 3                          9                           10
# 4                         10                           10
#
#    review_scores_location  review_scores_rating  review_scores_value  \
# 0                      10                    97                   10
# 1                      10                    98                    9
# 2                       9                    85                    8
# 3                       9                    93                    9
# 4                      10                    97                    9
#
#    reviews_per_month        room_type      scrape_id  security_deposit  \
# 0                  2  Entire home/apt 20190403130253               100
# 1                  1  Entire home/apt 20190403130253               nan
# 2                  0     Private room 20190403130253               200
# 3                  0     Private room 20190403130253               200
# 4                  0  Entire home/apt 20190403130253                 0
#
#                                                space  \
# 0  Newly remodeled, modern, and bright garden uni...
# 1  We live in a large Victorian house on a quiet ...
# 2  Room rental-sunny view room/sink/Wi Fi (inner ...
# 3  Room rental Sunny view Rm/Wi-Fi/TV/sink/large ...
# 4  Please send us a quick message before booking ...
#
#                                              summary  \
# 0  New update: the house next door is under const...
# 1                                                NaN
# 2  Nice and good public transportation.  7 minute...
# 3  Nice and good public transportation.  7 minute...
# 4  Pls email before booking.  Interior featured i...
#
#                                              transit  zipcode  weekly_price  \
# 0  *Public Transportation is 1/2 block away.  *Ce...    94117          1120
# 1  The train is two blocks away and you can stop ...    94110          1600
# 2         N Juda Muni and bus stop.  Street parking.    94117           485
# 3  N Juda Muni, Bus and UCSF Shuttle. small shopp...    94117           490
# 4                                                NaN    94117           nan
#
#    monthly_price
# 0           4200
# 1           5500
# 2           1685
# 3           1685
# 4            nan

# %% [markdown]
# **Airbnb Calendar Data**

# %%
#Preview calendar data
display(calendar.head())
# Out:
#    adjusted_price  available       date  listing_id  maximum_nights  \
# 0              80          0 2019-04-03      187730             120
# 1              80          0 2019-04-04      187730             120
# 2              82          1 2019-04-05      187730             120
# 3              82          1 2019-04-06      187730             120
# 4              81          1 2019-04-07      187730             120
#
#    minimum_nights  price
# 0               3     80
# 1               3     80
# 2               3     82
# 3               3     82
# 4               3     81

# %% [markdown]
# **Reviews Data**

# %%
#Preview zillow data
display(reviews.head())
# Out:
#                                                   comments       date  \
# 19330                                                  ... 2013-12-01
# 143113            Stop and book it now. Rea (Website hi... 2017-06-07
# 1021372          So I moved to SF in late May from Mich... 2013-06-02
# 64636            This was the perfect home from home, o... 2014-10-16
# 174143          We loved our time in beautiful SF! The ... 2018-08-10
#
#                 id  listing_id  reviewer_id      reviewer_name
# 19330      9000494      209514      9215434              Ramon
# 143113   158659946     4833101     35954713                Tim
# 1021372    4928809      635850      6542011            Michael
# 64636     21374058     1150867     13431837       Chris & Tess
# 174143   305042501     7226841     73281468  Jessica ( + Mark)

# %% [markdown]
# # Data Exploration

# %% [markdown]
# - How has Airbnb grown over the last year? Which neighborhoods have shown the most growth?
# - What are the metrics for the different neighborhoods in SF?
# - Are airbnb's that are available for monthly rent competitive with the local rent market? Is Airbnb a legitmate option to consider for short term living as opposed to finding month to month leases?
# - What are the different data distributions for the different outcome variables we are interested in exploring?

# %% [markdown]
# #### What are the different data distributions for the different outcome variables we are interested in exploring?

# %% [markdown]
# date

# %%
calendar.date.hist()

# %%
#plot hist
listings.review_scores_rating.hist(bins = 80)

#plot the mean
mean = np.mean(listings.review_scores_rating)

plt.axvline(mean, color='r', linewidth=2, linestyle='--', label= str(round(mean,2)))

# %% [markdown]
# Listings price

# %%
#KDE
ax = sns.kdeplot(listings.price, shade=True, color="grey")

#plot the mean
mean = np.mean(listings.price)

plt.axvline(mean, color='r', linewidth=2, linestyle='--', label= str(round(mean,2)))

# %%
listings.monthly_price.hist(bins = 30)

#plot the mean
mean = np.mean(listings.monthly_price)

plt.axvline(mean, color='r', linewidth=2, linestyle='--', label= str(round(mean,2)))

# %%
listings.weekly_price.hist(bins = 30)

#plot the mean
mean = np.mean(listings.weekly_price)

plt.axvline(mean, color='r', linewidth=2, linestyle='--', label= str(round(mean,2)))

# %% [markdown]
# #### Listings Outlier Removal for Price variable

# %%
#Set 538 plot style
plt.style.use('fivethirtyeight')

#Airbnb price distributions
listings.price.plot(kind = 'hist', bins=55,  title='Raw Data Airbnb Price Distribution in San Francisco',
          legend = True, figsize=(10,6));

#Get axis object
ax = plt.gca()

#Format axes
ax.get_xaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "$ {:,}".format(int(x))))
ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

#Mute grid lines
ax.grid(b=False, which ='major', axis = 'x')

#Set Path to write plot
path = r'C:\Users\kishe\Documents\Data Science\Projects\Python Projects\In Progress\Air BnB - SF\Output Files\Visualizations\Listings Data Distributions'

#Save plot to png
#plt.savefig(path + '\Listings Raw Data Price Distribution.png',bbox_inches = 'tight')

# %%
#Calculate IQR of price
q25 = listings['price'].quantile(0.25)
q75= listings['price'].quantile(0.75)
iqr = q75 - q25

#Print percentiles
print('Percentiles: 25th={:.3f}, 75th={:.3f} \nIQR= {:.3f}'.format(q25, q75, iqr))

#Calculate outlier cutoffs
cut_off =1.5 * iqr
lower, upper = q25 - cut_off, q75 + iqr

#Identify outliers
outliers = [x for x in listings.price if x < lower or x > upper]
print("Number of outliers identified: {}".format(len(outliers)))

#Remove outliers
outliers_removed = [x for x in listings.price if x >= lower and x <= upper]
print('Non-outlier observations: {}'.format(len(outliers_removed)))

#Update df
listings = listings[listings.price.isin(outliers_removed)]
print('Current listings shape:',listings.shape)
# Out:
# Percentiles: 25th=100.000, 75th=240.000
# IQR= 140.000
# Number of outliers identified: 10025
# Non-outlier observations: 88771
# Current listings shape: (88771, 68)

# %%
#Set ggplot plot style
plt.style.use('ggplot')

#Airbnb price distributions(outliers removed)
listings.price.plot(kind = 'hist', bins=40,  title='Price Distribution in San Francisco',
           figsize=(10,6));

#Capture mean and median of price
mean = listings.price.mean()
median = listings.price.median()

#Plot mean and median
plt.axvline(mean, color='white', linewidth=2, linestyle='--', label= 'AVG:'+ str(round(mean,2)))

#Get axis object
ax = plt.gca()

#Format axes
ax.get_xaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "${:,}".format(int(x))))
ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

#Mute grid lines
plt.grid(b=False, which ='major', axis = 'x')

#Set legend
plt.legend(loc='upper right',frameon=True, fancybox=True)

#Save plot to png
#plt.savefig(path + '\Listings Data Price Distribution.png',bbox_inches = 'tight')

# %% [markdown]
# Over the last year, there has been significant growth in the number of listings available for rent month to month. Let us look into the number of nights booked by users over the last year.

# %% [markdown]
# Latitude and longitude

# %%
fig, ax = plt.subplots(figsize = (15,15))

sns.scatterplot(x='longitude', y = 'latitude',hue = 'price', data = listings.iloc[:-1:70,:], ax = ax)

# %% [markdown]
# **Growth by neighborhood December 2018 - December 2019**
#
# We'll merge our calendar data with listings data to capture neighborhood data

# %%
#Pull month and year date from date column
calendar['year']= pd.DatetimeIndex(calendar['date']).year
calendar['month']= pd.DatetimeIndex(calendar['date']).month

#Set dates
calendar= calendar[(calendar.year == 2018) | (calendar.year == 2019)]

#Drop unnecessary columns for merge to preserve memory
temp = calendar.drop(columns=['price','maximum_nights','minimum_nights',
                             'available'])

# %%
#capture listing id and neighbourhood_cleansed from listings for merge
neighborhoods = listings[['id', 'neighbourhood_cleansed']]

#Merge with calendar
neighborhood_growth = temp.merge(neighborhoods, left_on ='listing_id', right_on='id')

#Drop redundant columns
neighborhood_growth= neighborhood_growth.drop(columns = ['id'])

#Drop Dupes
neighborhood_growth.drop_duplicates(inplace=True)

# %%
#Group last year by month_year and get a count of unique listings per month
neighborhood_growth = neighborhood_growth.groupby(['neighbourhood_cleansed', 'year', 'month'])['listing_id'].agg({'nunique'}).reset_index()

#Rename columns
neighborhood_growth =neighborhood_growth.rename(columns = {'neighbourhood_cleansed': 'neighborhoods',
                                                                 'nunique': 'listings'})

# %%
neighborhood_growth = neighborhood_growth.sort_values(by=['year','month', 'listings'], ascending=False)

# %%
#Set fig size
f, ax = plt.subplots(figsize = (6,15))

#set style and color_pallete
sns.set(style='whitegrid')

#Set color codes for modern data
sns.set_color_codes('pastel')

#plot data from 
j = sns.barplot(x = 'listings', y = 'neighborhoods', color = 'b',
            data = neighborhood_growth.loc[(neighborhood_growth.month == 12 ) & 
                                         (neighborhood_growth.year == 2019)],
                label = 'December 2019')

#Set color codes for older data
sns.set_color_codes('dark')

#Plot data from 2018-09
g = sns.barplot(x = 'listings', y = 'neighborhoods', color = 'b',
            data = neighborhood_growth.loc[(neighborhood_growth.month == 12 ) & 
                                         (neighborhood_growth.year == 2018)],
                label = 'December 2018')

#Set legend info
ax.legend(frameon = True, ncol = 2, loc= 'lower center');

#Set Labels
ax.set(ylabel="", xlabel="Airbnb Listings")
ax.set_title('Explosion of Airbnb', fontweight = 'bold', fontsize = 18)


sns.despine(left=True, bottom=True)

#Set Path to write plot
#path = r'C:\Users\kishe\Documents\Data Science\Projects\Python Projects\In Progress\Air BnB - SF\Output Files\Visualizations\Calendar Data Distributions'

#Save plot to png
#plt.savefig(path + '\Calendar Raw Data Distributions.png',bbox_inches = 'tight')

# %% [markdown]
# **Prices by property type**

# %% [markdown]
# Which neighborhoods are the nicest? Which are the safest? Refercne the review scores and location rating in listings

# %%
#Set 538 plot style
plt.style.use('ggplot')

#Counts of property types
prop_count = listings.groupby('property_type')['id'].count().sort_values(ascending = False).reset_index()
prop_count.plot(x = 'property_type', y = 'id', kind = 'bar')

# %%
#Get top 15 common prop types
prop_list=list(prop_count.property_type.head(15))

#sort top 15 by median value
test = listings[listings.property_type.isin(prop_list)].groupby('property_type')['price'].median().sort_values(ascending = False).reset_index()

# %%
test_list = test.property_type.tolist()

# %%
#Set 538 plot style
#plt.style.use('fivethirtyeight')

#Set Figure
f, ax = plt.subplots(figsize= (15,5))

#Plot
g= sns.boxplot(x="property_type", y="price",hue = 'host_is_superhost', order=test_list,
                data=listings[listings.property_type.isin(test_list)], ax=ax)

#Set Title
ax.set_title('15 Most common properties with listing price', fontweight = 'bold', fontsize=22)

#Set fontdict
fontdict={'weight' : 'bold',
          'size': 17}

#Set x and y Labels
ax.set_ylabel('Price per Night($)',fontdict=fontdict)
ax.set_xlabel('Property Type',fontdict=fontdict)

#Rotate x_ticklabels
g.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right');

#Format ticks on y-axis

# %% [markdown]
# **Heat map**

# %%
corr = listings.corr()
plt.figure(figsize=(15, 15))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,linewidths=.1,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\numpy\core\function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     116     try:
# --> 117         num = operator.index(num)
#     118     except TypeError:
#
# TypeError: 'float' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-294ae7af3d90> in <module>
#       4     corr,
#       5     vmin=-1, vmax=1, center=0,linewidths=.1,
# ----> 6     cmap=sns.diverging_palette(20, 220, n=200),
#       7     square=True
#       8 )
#
# ~\AppData\Roaming\Python\Python37\site-packages\seaborn\palettes.py in diverging_palette(h_neg, h_pos, s, l, sep, n, center, as_cmap)
#     742     """
#     743     palfunc = dark_palette if center == "dark" else light_palette
# --> 744     neg = palfunc((h_neg, s, l), 128 - (sep / 2), reverse=True, input="husl")
#     745     pos = palfunc((h_pos, s, l), 128 - (sep / 2), input="husl")
#     746     midpoint = dict(light=[(.95, .95, .95, 1.)],
#
# ~\AppData\Roaming\Python\Python37\site-packages\seaborn\palettes.py in light_palette(color, n_colors, reverse, as_cmap, input)
#     639     light = set_hls_values(color, l=.95)  # noqa
#     640     colors = [color, light] if reverse else [light, color]
# --> 641     return blend_palette(colors, n_colors, as_cmap)
#     642
#     643
#
# ~\AppData\Roaming\Python\Python37\site-packages\seaborn\palettes.py in blend_palette(colors, n_colors, as_cmap, input)
#     775     pal = mpl.colors.LinearSegmentedColormap.from_list(name, colors)
#     776     if not as_cmap:
# --> 777         pal = _ColorPalette(pal(np.linspace(0, 1, n_colors)))
#     778     return pal
#     779
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# ~\Miniconda3\lib\site-packages\numpy\core\function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     119         raise TypeError(
#     120             "object of type {} cannot be safely interpreted as an integer."
# --> 121                 .format(type(num)))
#     122
#     123     if num < 0:
#
# TypeError: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
sns.scatterplot(x = 'cleaning_fee', y='price', data = listings)

# %% [markdown]
# #Superhost?

# %% [markdown]
# Explore what makes a super host.
# Why would you want to be a super host
# What advantages can you find to being a super host? (higher reviews, higher rent, more business?)

# %%
len(listings[listings.host_is_superhost == False])

# %%
#Add values
sns.boxplot( x = 'host_is_superhost', y='price', data = listings)

# %% [markdown]
# Who owns the most Airbnb properties?

# %% [markdown]
# https://towardsdatascience.com/airbnb-rental-listings-dataset-mining-f972ed08ddec

# %%
len(listings[listings.host_is_superhost == False])

# %%
test = listings.groupby(['host_id'])['id'].agg({'nunique'}).sort_values(by ='nunique', ascending =False).reset_index()

#Get a list of the properties owned by the top host ids
test_list = list(test.host_id.head(10))#might be worth doing more than 10, maybe anything more than listing id1?
#would differentitate the average host? Perhaps calculate aberage lisitng ids per host and get the outliers?

#get the listings data
listings[listings.host_id.isin(test_list)].head(10).T

# %% [markdown]
# When is the cheapest days for travel? How do prices compare during holiday>

# %%
#Set path to write listings
path = r'C:\Users\kishe\Documents\Data Science\Projects\Python Projects\In Progress\Air BnB - SF\Data\03_Processed\01_16_2020_Listings_Post_EDA.csv'

#Write listings to path
listings.to_csv(path, sep=',')
