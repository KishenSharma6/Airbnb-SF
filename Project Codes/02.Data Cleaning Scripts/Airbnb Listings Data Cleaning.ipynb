# %% [markdown]
# # Data Cleaning - Airbnb Listings

# %% [markdown]
# ## Introduction
#
# In the following notebook, I will be cleaning an aggregation of Airbnb Listings Data of the San Francisco area. This aggregation consists of listings data from 11/2018 through 10/2019.
#
# The aggregation source code can be found [here](https://github.com/KishenSharma6/Airbnb-SF_ML_-_Text_Analysis/blob/master/Airbnb%20Raw%20Data%20Aggregation.ipynb)
#
# Raw data can be found [here](https://github.com/KishenSharma6/Airbnb-SF_ML_-_Text_Analysis/tree/master/Data/01_Raw/SF%20Airbnb%20Raw%20Data)

# %%
#Read in libraries
import dask.dataframe as dd
import swifter

import pandas as pd
import pandas_profiling

import re

import numpy as np
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Set Additional Settings for Notebook**

# %%
#supress future warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#Set plot aesthetics for notebook
sns.set(style='whitegrid', palette='pastel', color_codes=True)

#Increase number of columns and rows displayed by Pandas
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows',200)

# %% [markdown]
# **Read in Data**

# %%
#Set path to get aggregated listings data
path = r'C:\Users\kishe\Documents\Data Science\Projects\Python Projects\In Progress\Air BnB - SF\SF Airbnb Raw Data - Aggregated\12_26_2019_Listings.csv'

#Read in Airbnb Listings Data
listings = pd.read_csv(path,index_col=0, low_memory=False, sep=',')

# %% [markdown]
# ## Pandas Profiling Report

# %%
# #Create Pandas Profiling Report for listings data
# profile = listings.profile_report(title='Airbnb Listings Report')

# #Write profile to an HTML file
# profile.to_file(output_file="Airbnb Listings Report.html")

# #Capture rejected variables
# rejected_variables = profile.get_rejected_variables(threshold=0.9)

# #View variables that were rejected
# print('Variables rejected for having a greater collinearity than .9:', rejected_variables)

# %%
# #Variables rejected for having a collinearity > .9
# ['availability_60', 'availability_90', 'calculated_host_listings_count_entire_homes', 'country_code', 
# 'host_total_listings_count', 'last_scraped', 'maximum_minimum_nights', 'maximum_nights', 
# 'maximum_nights_avg_ntm', 'minimum_maximum_nights', 'minimum_minimum_nights', 'minimum_nights', 'minimum_nights_avg_ntm']

# %%
# #View pandas profile for Listings data
# profile

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Preview data in original format**

# %%
#Print original listings shape
print('Original listings shape:',listings.shape)

#View listings head
display(listings.head())
# Out:
# Original listings shape: (88937, 106)
#                                               access  accommodates  \
# 0  *Full access to patio and backyard (shared wit...             3
# 1  Our deck, garden, gourmet kitchen and extensiv...             5
# 2                                                NaN             2
# 3                                                NaN             2
# 4  Guests have access to everything listed and sh...             5
#
#                                            amenities  availability_30  \
# 0  {TV,"Cable TV",Internet,Wifi,Kitchen,"Pets liv...                0
# 1  {Internet,Wifi,Kitchen,Heating,"Family/kid fri...                0
# 2  {TV,Internet,Wifi,Kitchen,"Free street parking...               30
# 3  {TV,Internet,Wifi,Kitchen,"Free street parking...               30
# 4  {TV,Internet,Wifi,Kitchen,Heating,"Family/kid ...               30
#
#    availability_365  availability_60  availability_90  bathrooms  bed_type  \
# 0                77                0                1        1.0  Real Bed
# 1                 0                0                0        1.0  Real Bed
# 2               365               60               90        4.0  Real Bed
# 3               365               60               90        4.0  Real Bed
# 4                90               60               90        1.5  Real Bed
#
#    bedrooms  beds  calculated_host_listings_count  \
# 0       1.0   2.0                               1
# 1       2.0   3.0                               1
# 2       1.0   1.0                               9
# 3       1.0   1.0                               9
# 4       2.0   2.0                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                          1.0
# 1                                          1.0
# 2                                          0.0
# 3                                          0.0
# 4                                          2.0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                           0.0
# 1                                           0.0
# 2                                           9.0
# 3                                           9.0
# 4                                           0.0
#
#    calculated_host_listings_count_shared_rooms calendar_last_scraped  \
# 0                                          0.0            2019-04-03
# 1                                          0.0            2019-04-03
# 2                                          0.0            2019-04-03
# 3                                          0.0            2019-04-03
# 4                                          0.0            2019-04-03
#
#   calendar_updated          cancellation_policy           city cleaning_fee  \
# 0       a week ago                     moderate  San Francisco      $100.00
# 1     4 months ago  strict_14_with_grace_period  San Francisco      $100.00
# 2    17 months ago  strict_14_with_grace_period  San Francisco       $50.00
# 3    17 months ago  strict_14_with_grace_period  San Francisco       $50.00
# 4     4 months ago  strict_14_with_grace_period  San Francisco      $225.00
#
#          country country_code  \
# 0  United States           US
# 1  United States           US
# 2  United States           US
# 3  United States           US
# 4  United States           US
#
#                                          description experiences_offered  \
# 0  New update: the house next door is under const...                none
# 1  We live in a large Victorian house on a quiet ...                none
# 2  Nice and good public transportation.  7 minute...                none
# 3  Nice and good public transportation.  7 minute...                none
# 4  Pls email before booking.  Interior featured i...                none
#
#   extra_people first_review  guests_included has_availability  \
# 0       $25.00   2009-07-23                2                t
# 1        $0.00   2009-05-03                2                t
# 2       $12.00   2009-08-31                1                t
# 3       $12.00   2014-09-08                1                t
# 4      $150.00   2009-09-25                2                t
#
#                                           host_about  host_acceptance_rate  \
# 0  We are a family with 2 boys born in 2009 and 2...                   NaN
# 1  Philip: English transplant to the Bay Area and...                   NaN
# 2  7 minutes walk to UCSF.  15 minutes walk to US...                   NaN
# 3  7 minutes walk to UCSF.  15 minutes walk to US...                   NaN
# 4  Always searching for a perfect piece at Europe...                   NaN
#
#   host_has_profile_pic  host_id host_identity_verified host_is_superhost  \
# 0                    t     1169                      t                 t
# 1                    t     8904                      t                 f
# 2                    t    21994                      t                 f
# 3                    t    21994                      t                 f
# 4                    t    24215                      t                 f
#
#    host_listings_count                             host_location  \
# 0                  1.0  San Francisco, California, United States
# 1                  2.0  San Francisco, California, United States
# 2                 10.0  San Francisco, California, United States
# 3                 10.0  San Francisco, California, United States
# 4                  2.0  San Francisco, California, United States
#
#           host_name host_neighbourhood  \
# 0             Holly    Duboce Triangle
# 1  Philip And Tania     Bernal Heights
# 2             Aaron        Cole Valley
# 3             Aaron        Cole Valley
# 4              Rosy       Alamo Square
#
#                                     host_picture_url host_response_rate  \
# 0  https://a0.muscache.com/im/pictures/efdad96a-3...               100%
# 1  https://a0.muscache.com/im/users/8904/profile_...                80%
# 2  https://a0.muscache.com/im/users/21994/profile...               100%
# 3  https://a0.muscache.com/im/users/21994/profile...               100%
# 4  https://a0.muscache.com/im/users/24215/profile...               100%
#
#    host_response_time  host_since  \
# 0      within an hour  2008-07-31
# 1        within a day  2009-03-02
# 2  within a few hours  2009-06-17
# 3  within a few hours  2009-06-17
# 4      within an hour  2009-07-02
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/efdad96a-3...
# 1  https://a0.muscache.com/im/users/8904/profile_...
# 2  https://a0.muscache.com/im/users/21994/profile...
# 3  https://a0.muscache.com/im/users/21994/profile...
# 4  https://a0.muscache.com/im/users/24215/profile...
#
#    host_total_listings_count                                 host_url  \
# 0                        1.0   https://www.airbnb.com/users/show/1169
# 1                        2.0   https://www.airbnb.com/users/show/8904
# 2                       10.0  https://www.airbnb.com/users/show/21994
# 3                       10.0  https://www.airbnb.com/users/show/21994
# 4                        2.0  https://www.airbnb.com/users/show/24215
#
#                                   host_verifications  \
# 0   ['email', 'phone', 'facebook', 'reviews', 'kba']
# 1  ['email', 'phone', 'reviews', 'kba', 'work_ema...
# 2  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 3  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 4               ['email', 'phone', 'reviews', 'kba']
#
#                                          house_rules    id instant_bookable  \
# 0  * No Pets - even visiting guests for a short t...   958                t
# 1  Please respect the house, the art work, the fu...  5858                f
# 2  No party, No smoking, not for any kinds of smo...  7918                f
# 3       no pet no smoke no party inside the building  8142                f
# 4  House Manual and House Rules will be provided ...  8339                f
#
#                                          interaction is_business_travel_ready  \
# 0  A family of 4 lives upstairs with their dog. N...                        f
# 1                                                NaN                        f
# 2                                                NaN                        f
# 3                                                NaN                        f
# 4                                                NaN                        f
#
#   is_location_exact jurisdiction_names last_review last_scraped  latitude  \
# 0                 t  {"SAN FRANCISCO"}  2019-03-16   2019-04-03  37.76931
# 1                 t  {"SAN FRANCISCO"}  2017-08-06   2019-04-03  37.74511
# 2                 t  {"SAN FRANCISCO"}  2016-11-21   2019-04-03  37.76669
# 3                 t  {"SAN FRANCISCO"}  2018-09-12   2019-04-03  37.76487
# 4                 t  {"SAN FRANCISCO"}  2018-08-11   2019-04-03  37.77525
#
#        license                        listing_url  longitude         market  \
# 0  STR-0001256   https://www.airbnb.com/rooms/958 -122.43386  San Francisco
# 1          NaN  https://www.airbnb.com/rooms/5858 -122.42102  San Francisco
# 2          NaN  https://www.airbnb.com/rooms/7918 -122.45250  San Francisco
# 3          NaN  https://www.airbnb.com/rooms/8142 -122.45183  San Francisco
# 4  STR-0000264  https://www.airbnb.com/rooms/8339 -122.43637  San Francisco
#
#    maximum_maximum_nights  maximum_minimum_nights  maximum_nights  \
# 0                    30.0                     1.0              30
# 1                    60.0                    30.0              60
# 2                    60.0                    32.0              60
# 3                    90.0                    32.0              90
# 4                  1125.0                     7.0            1125
#
#    maximum_nights_avg_ntm  medium_url  minimum_maximum_nights  \
# 0                    30.0         NaN                    30.0
# 1                    60.0         NaN                    60.0
# 2                    60.0         NaN                    60.0
# 3                    90.0         NaN                    90.0
# 4                  1125.0         NaN                  1125.0
#
#    minimum_minimum_nights  minimum_nights  minimum_nights_avg_ntm  \
# 0                     1.0               1                     1.0
# 1                    30.0              30                    30.0
# 2                    32.0              32                    32.0
# 3                    32.0              32                    32.0
# 4                     7.0               7                     7.0
#
#   monthly_price                                               name  \
# 0     $4,200.00                Bright, Modern Garden Unit - 1BR/1B
# 1     $5,500.00                                 Creative Sanctuary
# 2     $1,685.00         A Friendly Room - UCSF/USF - San Francisco
# 3     $1,685.00  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4           NaN                    Historic Alamo Square Victorian
#
#                                neighborhood_overview          neighbourhood  \
# 0  *Quiet cul de sac in friendly neighborhood *St...        Duboce Triangle
# 1  I love how our neighborhood feels quiet but is...         Bernal Heights
# 2  Shopping old town, restaurants, McDonald, Whol...            Cole Valley
# 3                                                NaN            Cole Valley
# 4                                                NaN  Western Addition/NOPA
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed  \
# 0       Western Addition                           NaN
# 1         Bernal Heights                           NaN
# 2         Haight Ashbury                           NaN
# 3         Haight Ashbury                           NaN
# 4       Western Addition                           NaN
#
#                                                notes  number_of_reviews  \
# 0  Due to the fact that we have children and a do...                183
# 1  All the furniture in the house was handmade so...                111
# 2  Please email your picture id with print name (...                 17
# 3  Please email your picture id with print name (...                  8
# 4                      tax ID on file tax ID on file                 27
#
#    number_of_reviews_ltm                                        picture_url  \
# 0                   51.0  https://a0.muscache.com/im/pictures/b7c2a199-4...
# 1                    0.0  https://a0.muscache.com/im/pictures/17714/3a7a...
# 2                    0.0  https://a0.muscache.com/im/pictures/26356/8030...
# 3                    1.0  https://a0.muscache.com/im/pictures/27832/3b1f...
# 4                    1.0  https://a0.muscache.com/im/pictures/6f84a7c2-e...
#
#      price property_type require_guest_phone_verification  \
# 0  $170.00     Apartment                                f
# 1  $235.00     Apartment                                f
# 2   $65.00     Apartment                                f
# 3   $65.00     Apartment                                f
# 4  $785.00         House                                t
#
#   require_guest_profile_picture requires_license  review_scores_accuracy  \
# 0                             f                t                    10.0
# 1                             f                t                    10.0
# 2                             f                t                     8.0
# 3                             f                t                     9.0
# 4                             t                t                    10.0
#
#    review_scores_checkin  review_scores_cleanliness  \
# 0                   10.0                       10.0
# 1                   10.0                       10.0
# 2                    9.0                        8.0
# 3                   10.0                        9.0
# 4                   10.0                       10.0
#
#    review_scores_communication  review_scores_location  review_scores_rating  \
# 0                         10.0                    10.0                  97.0
# 1                         10.0                    10.0                  98.0
# 2                          9.0                     9.0                  85.0
# 3                         10.0                     9.0                  93.0
# 4                         10.0                    10.0                  97.0
#
#    review_scores_value  reviews_per_month        room_type     scrape_id  \
# 0                 10.0               1.55  Entire home/apt  2.019040e+13
# 1                  9.0               0.92  Entire home/apt  2.019040e+13
# 2                  8.0               0.15     Private room  2.019040e+13
# 3                  9.0               0.14     Private room  2.019040e+13
# 4                  9.0               0.23  Entire home/apt  2.019040e+13
#
#   security_deposit     smart_location  \
# 0          $100.00  San Francisco, CA
# 1              NaN  San Francisco, CA
# 2          $200.00  San Francisco, CA
# 3          $200.00  San Francisco, CA
# 4            $0.00  San Francisco, CA
#
#                                                space  square_feet state  \
# 0  Newly remodeled, modern, and bright garden uni...          NaN    CA
# 1  We live in a large Victorian house on a quiet ...          NaN    CA
# 2  Room rental-sunny view room/sink/Wi Fi (inner ...          NaN    CA
# 3  Room rental Sunny view Rm/Wi-Fi/TV/sink/large ...          NaN    CA
# 4  Please send us a quick message before booking ...          NaN    CA
#
#                              street  \
# 0  San Francisco, CA, United States
# 1  San Francisco, CA, United States
# 2  San Francisco, CA, United States
# 3  San Francisco, CA, United States
# 4  San Francisco, CA, United States
#
#                                              summary  thumbnail_url  \
# 0  New update: the house next door is under const...            NaN
# 1                                                NaN            NaN
# 2  Nice and good public transportation.  7 minute...            NaN
# 3  Nice and good public transportation.  7 minute...            NaN
# 4  Pls email before booking.  Interior featured i...            NaN
#
#                                              transit weekly_price  \
# 0  *Public Transportation is 1/2 block away.  *Ce...    $1,120.00
# 1  The train is two blocks away and you can stop ...    $1,600.00
# 2         N Juda Muni and bus stop.  Street parking.      $485.00
# 3  N Juda Muni, Bus and UCSF Shuttle. small shopp...      $490.00
# 4                                                NaN          NaN
#
#    xl_picture_url zipcode
# 0             NaN   94117
# 1             NaN   94110
# 2             NaN   94117
# 3             NaN   94117
# 4             NaN   94117

# %% [markdown]
# ### Column Removal

# %% [markdown]
# **Removing rejected columns from Pandas Report**
#
# These columns have a correlation of over 90% with another variable in the dataset.

# %%
#Create list of columns to drop
collinear= ['availability_60', 'availability_90', 'calculated_host_listings_count_entire_homes', 'country_code', 
'host_total_listings_count', 'last_scraped', 'maximum_minimum_nights', 'maximum_nights', 
'maximum_nights_avg_ntm', 'minimum_maximum_nights', 'minimum_minimum_nights', 'minimum_nights', 'minimum_nights_avg_ntm']

#Remove collinear columns from listings
listings.drop(columns = collinear, inplace = True)

#Updated listings shape
print('Updated listings shape:', listings.shape)
# Out:
# Updated listings shape: (88937, 93)

# %% [markdown]
# **Removing redundant columns**
#
# Columns city, street, and smart_location appear to encode the same information. Columns neighbourhood and neighbourhood_cleansed also appear to do the same.
#
# Keeping city and neighbourhood_cleansed

# %%
#Cols to drop
cols = ['street', 'smart_location','neighbourhood']

#Dropping redundant columns
listings.drop(columns=cols, inplace=True)

#Updated listings shape
print('Updated listings shape:', listings.shape)
# Out:
# Updated listings shape: (88937, 90)

# %% [markdown]
# **Remove columns with homogenous values**

# %%
#Capture columns with homogeneous values and store as list in cols
cols = list(listings.columns[listings.nunique() <= 1])

#Drop cols
listings.drop(columns=cols, axis = 1, inplace=True)

#Updated listings shape
print('Updated listings shape:', listings.shape)
# Out:
# Updated listings shape: (88937, 80)

# %% [markdown]
# **Check for additional columns with mostly homogenous values**

# %%
#Capture columns with homogeneous values and store as list in cols
print(listings.columns[listings.nunique() <= 2])

#Per Pandas Report, state and country are not boolean values
#Investigating rows where listings.country == 'Mexico'
listings[listings.country == 'Mexico']
# Out:
# Index(['country', 'host_has_profile_pic', 'host_identity_verified',
#        'host_is_superhost', 'instant_bookable', 'is_location_exact',
#        'require_guest_phone_verification', 'require_guest_profile_picture',
#        'requires_license', 'state'],
#       dtype='object')
#       access  accommodates                                          amenities  \
# 4767     NaN             6  {TV,Internet,Wifi,"Air conditioning",Kitchen,E...
# 20223    NaN             6  {TV,Internet,Wifi,"Air conditioning",Kitchen,E...
# 27186    NaN             6  {TV,Internet,Wifi,"Air conditioning",Kitchen,E...
# 34502    NaN             6  {TV,Internet,Wifi,"Air conditioning",Kitchen,E...
# 56734    NaN             6  {TV,Internet,Wifi,"Air conditioning",Kitchen,E...
#
#        availability_30  availability_365  bathrooms  bed_type  bedrooms  beds  \
# 4767                 0                 0        3.5  Real Bed       3.0   4.0
# 20223               10                25        3.5  Real Bed       3.0   4.0
# 27186                7                 7        3.5  Real Bed       3.0   4.0
# 34502               11                14        3.5  Real Bed       3.0   4.0
# 56734                0                 0        3.5  Real Bed       3.0   4.0
#
#        calculated_host_listings_count  \
# 4767                                1
# 20223                               2
# 27186                               1
# 34502                               1
# 56734                               1
#
#        calculated_host_listings_count_private_rooms  \
# 4767                                            0.0
# 20223                                           NaN
# 27186                                           0.0
# 34502                                           0.0
# 56734                                           0.0
#
#        calculated_host_listings_count_shared_rooms calendar_last_scraped  \
# 4767                                           0.0            2019-04-03
# 20223                                          NaN            2018-12-06
# 27186                                          0.0            2019-02-01
# 34502                                          0.0            2019-01-09
# 56734                                          0.0            2019-03-06
#
#       calendar_updated cancellation_policy           city cleaning_fee  \
# 4767             today     super_strict_60  San Francisco        $0.00
# 20223            today     super_strict_60  San Francisco        $0.00
# 27186            today     super_strict_60  San Francisco        $0.00
# 34502        yesterday     super_strict_60  San Francisco        $0.00
# 56734            today     super_strict_60  San Francisco        $0.00
#
#       country                                        description extra_people  \
# 4767   Mexico  ONEFINESTAY is proud to present this 3 bedroom...        $0.00
# 20223  Mexico  ONEFINESTAY is proud to present this 3 bedroom...        $0.00
# 27186  Mexico  ONEFINESTAY is proud to present this 3 bedroom...        $0.00
# 34502  Mexico  ONEFINESTAY is proud to present this 3 bedroom...        $0.00
# 56734  Mexico  ONEFINESTAY is proud to present this 3 bedroom...        $0.00
#
#       first_review  guests_included  \
# 4767           NaN                6
# 20223          NaN                6
# 27186          NaN                6
# 34502          NaN                6
# 56734          NaN                6
#
#                                               host_about host_has_profile_pic  \
# 4767   Hi, \r\n\r\nMy name is Sally and I am part of ...                    t
# 20223  Hi, \r\n\r\nMy name is Sally and I am part of ...                    t
# 27186  Hi, \r\n\r\nMy name is Sally and I am part of ...                    t
# 34502  Hi, \r\n\r\nMy name is Sally and I am part of ...                    t
# 56734  Hi, \r\n\r\nMy name is Sally and I am part of ...                    t
#
#          host_id host_identity_verified host_is_superhost  \
# 4767   156158778                      f                 f
# 20223  156158778                      f                 f
# 27186  156158778                      f                 f
# 34502  156158778                      f                 f
# 56734  156158778                      f                 f
#
#        host_listings_count                    host_location host_name  \
# 4767                 458.0  London, England, United Kingdom     Sally
# 20223                419.0  London, England, United Kingdom     Sally
# 27186                394.0  London, England, United Kingdom     Sally
# 34502                390.0  London, England, United Kingdom     Sally
# 56734                394.0  London, England, United Kingdom     Sally
#
#       host_neighbourhood                                   host_picture_url  \
# 4767           Battersea  https://a0.muscache.com/im/pictures/user/e7869...
# 20223          Battersea  https://a0.muscache.com/im/pictures/user/e7869...
# 27186          Battersea  https://a0.muscache.com/im/pictures/user/e7869...
# 34502          Battersea  https://a0.muscache.com/im/pictures/user/e7869...
# 56734          Battersea  https://a0.muscache.com/im/pictures/user/e7869...
#
#       host_response_rate host_response_time  host_since  \
# 4767                100%     within an hour  2017-10-25
# 20223               100%     within an hour  2017-10-25
# 27186                97%     within an hour  2017-10-25
# 34502                NaN                NaN  2017-10-25
# 56734               100%     within an hour  2017-10-25
#
#                                       host_thumbnail_url  \
# 4767   https://a0.muscache.com/im/pictures/user/e7869...
# 20223  https://a0.muscache.com/im/pictures/user/e7869...
# 27186  https://a0.muscache.com/im/pictures/user/e7869...
# 34502  https://a0.muscache.com/im/pictures/user/e7869...
# 56734  https://a0.muscache.com/im/pictures/user/e7869...
#
#                                           host_url  \
# 4767   https://www.airbnb.com/users/show/156158778
# 20223  https://www.airbnb.com/users/show/156158778
# 27186  https://www.airbnb.com/users/show/156158778
# 34502  https://www.airbnb.com/users/show/156158778
# 56734  https://www.airbnb.com/users/show/156158778
#
#                      host_verifications  \
# 4767   ['email', 'phone', 'work_email']
# 20223  ['email', 'phone', 'work_email']
# 27186  ['email', 'phone', 'work_email']
# 34502  ['email', 'phone', 'work_email']
# 56734  ['email', 'phone', 'work_email']
#
#                                            house_rules        id  \
# 4767   Pets not allowed. Check in from 16:00 to 16:00.  23298702
# 20223  Pets not allowed. Check in from 16:00 to 16:00.  23298702
# 27186  Pets not allowed. Check in from 16:00 to 16:00.  23298702
# 34502  Pets not allowed. Check in from 16:00 to 16:00.  23298702
# 56734  Pets not allowed. Check in from 16:00 to 16:00.  23298702
#
#       instant_bookable interaction is_location_exact last_review   latitude  \
# 4767                 t         NaN                 f         NaN  37.795740
# 20223                t         NaN                 f         NaN  37.795744
# 27186                t         NaN                 f         NaN  37.795744
# 34502                t         NaN                 f         NaN  37.795744
# 56734                t         NaN                 f         NaN  37.795740
#
#       license                            listing_url   longitude  \
# 4767      NaN  https://www.airbnb.com/rooms/23298702 -122.425660
# 20223     NaN  https://www.airbnb.com/rooms/23298702 -122.425657
# 27186     NaN  https://www.airbnb.com/rooms/23298702 -122.425657
# 34502     NaN  https://www.airbnb.com/rooms/23298702 -122.425657
# 56734     NaN  https://www.airbnb.com/rooms/23298702 -122.425660
#
#        maximum_maximum_nights monthly_price  \
# 4767                   1125.0           NaN
# 20223                     NaN           NaN
# 27186                  1125.0           NaN
# 34502                  1125.0           NaN
# 56734                  1125.0           NaN
#
#                                          name neighborhood_overview  \
# 4767   Three Bridges Penthouse by ONEFINESTAY                   NaN
# 20223  Three Bridges Penthouse by ONEFINESTAY                   NaN
# 27186  Three Bridges Penthouse by ONEFINESTAY                   NaN
# 34502  Three Bridges Penthouse by ONEFINESTAY                   NaN
# 56734  Three Bridges Penthouse by ONEFINESTAY                   NaN
#
#       neighbourhood_cleansed  \
# 4767         Pacific Heights
# 20223        Pacific Heights
# 27186        Pacific Heights
# 34502        Pacific Heights
# 56734        Pacific Heights
#
#                                                    notes  number_of_reviews  \
# 4767   Home Truths:  - There is a dedicated elevator ...                  0
# 20223  Home Truths:  - There is a dedicated elevator ...                  0
# 27186  Home Truths:  - There is a dedicated elevator ...                  0
# 34502  Home Truths:  - There is a dedicated elevator ...                  0
# 56734  Home Truths:  - There is a dedicated elevator ...                  0
#
#        number_of_reviews_ltm  \
# 4767                     0.0
# 20223                    NaN
# 27186                    0.0
# 34502                    0.0
# 56734                    0.0
#
#                                              picture_url      price  \
# 4767   https://a0.muscache.com/im/pictures/f00cf518-5...  $8,000.00
# 20223  https://a0.muscache.com/im/pictures/f00cf518-5...  $8,000.00
# 27186  https://a0.muscache.com/im/pictures/f00cf518-5...  $8,000.00
# 34502  https://a0.muscache.com/im/pictures/f00cf518-5...  $8,000.00
# 56734  https://a0.muscache.com/im/pictures/f00cf518-5...  $8,000.00
#
#       property_type require_guest_phone_verification  \
# 4767      Apartment                                f
# 20223     Apartment                                f
# 27186     Apartment                                f
# 34502     Apartment                                f
# 56734     Apartment                                f
#
#       require_guest_profile_picture requires_license  review_scores_accuracy  \
# 4767                              f                f                     NaN
# 20223                             f                f                     NaN
# 27186                             f                f                     NaN
# 34502                             f                f                     NaN
# 56734                             f                f                     NaN
#
#        review_scores_checkin  review_scores_cleanliness  \
# 4767                     NaN                        NaN
# 20223                    NaN                        NaN
# 27186                    NaN                        NaN
# 34502                    NaN                        NaN
# 56734                    NaN                        NaN
#
#        review_scores_communication  review_scores_location  \
# 4767                           NaN                     NaN
# 20223                          NaN                     NaN
# 27186                          NaN                     NaN
# 34502                          NaN                     NaN
# 56734                          NaN                     NaN
#
#        review_scores_rating  review_scores_value  reviews_per_month  \
# 4767                    NaN                  NaN                NaN
# 20223                   NaN                  NaN                NaN
# 27186                   NaN                  NaN                NaN
# 34502                   NaN                  NaN                NaN
# 56734                   NaN                  NaN                NaN
#
#              room_type     scrape_id security_deposit  \
# 4767   Entire home/apt  2.019040e+13        $1,500.00
# 20223  Entire home/apt  2.018121e+13        $1,500.00
# 27186  Entire home/apt  2.019020e+13        $1,500.00
# 34502  Entire home/apt  2.019011e+13        $1,500.00
# 56734  Entire home/apt  2.019031e+13        $1,500.00
#
#                                                    space  square_feet state  \
# 4767   Included amenities: Wifi, iPhone, Welcome Pack...          NaN   NaN
# 20223  Included amenities: Wifi, iPhone, Welcome Pack...          NaN   NaN
# 27186  Included amenities: Wifi, iPhone, Welcome Pack...          NaN   NaN
# 34502  Included amenities: Wifi, iPhone, Welcome Pack...          NaN   NaN
# 56734  Included amenities: Wifi, iPhone, Welcome Pack...          NaN   NaN
#
#                                                  summary transit weekly_price  \
# 4767   ONEFINESTAY is proud to present this 3 bedroom...     NaN          NaN
# 20223  ONEFINESTAY is proud to present this 3 bedroom...     NaN          NaN
# 27186  ONEFINESTAY is proud to present this 3 bedroom...     NaN          NaN
# 34502  ONEFINESTAY is proud to present this 3 bedroom...     NaN          NaN
# 56734  ONEFINESTAY is proud to present this 3 bedroom...     NaN          NaN
#
#        zipcode
# 4767     94109
# 20223  94109.0
# 27186    94109
# 34502    94109
# 56734    94109

# %% [markdown]
# Rows with Mexico in the country column belong to the same host. This listing is in Pacifica Heights, a neighborhood in San Francisco. We can remove country and state column for containing mostly homogenous values.

# %%
#Dropping country column
listings.drop(columns=['country','state'], inplace = True)

#Updated listings shape
print('Updated listings shape:', listings.shape)
# Out:
# Updated listings shape: (88937, 78)

# %% [markdown]
# **Remove columns with majority NA values**
#
# Columns with greater than 30% missing values will be removed.

# %%
#Calculate which columns have mostly NA values
print(listings.isnull().mean().sort_values(ascending=False).head(15))
# Out:
# square_feet               0.982673
# monthly_price             0.847757
# weekly_price              0.846217
# notes                     0.380764
# license                   0.359266
# access                    0.338228
# interaction               0.327501
# transit                   0.290936
# neighborhood_overview     0.265739
# house_rules               0.264524
# host_about                0.239158
# security_deposit          0.203695
# review_scores_value       0.196836
# review_scores_checkin     0.196780
# review_scores_location    0.196780
# dtype: float64

# %% [markdown]
# Keeping weekly_price and monthly_price, missing value would indicate that the listing is unavailable for use of over 7 or 30 days respectively

# %%
#Store weekly_price and monthly_price
keep = listings[['weekly_price', 'monthly_price']]

#Dropping columns with more than 30% values missing
listings= listings[listings.columns[(listings.isnull().mean() < .30 )]]

#Concatenate keep cols back into listings
pd.concat([listings, keep], axis=1)

#Updated listings shape
#print('Updated listings shape:', listings.shape)
# Out:
#        accommodates                                          amenities  \
# 0                 3  {TV,"Cable TV",Internet,Wifi,Kitchen,"Pets liv...
# 1                 5  {Internet,Wifi,Kitchen,Heating,"Family/kid fri...
# 2                 2  {TV,Internet,Wifi,Kitchen,"Free street parking...
# 3                 2  {TV,Internet,Wifi,Kitchen,"Free street parking...
# 4                 5  {TV,Internet,Wifi,Kitchen,Heating,"Family/kid ...
# ...             ...                                                ...
# 88932             5  {TV,Wifi,"Free parking on premises","Free stre...
# 88933             4  {TV,Internet,Wifi,Kitchen,"Free street parking...
# 88934             4  {TV,Wifi,Kitchen,"Free parking on premises","P...
# 88935             2  {Wifi,"Smoke detector","Carbon monoxide detect...
# 88936             2  {TV,Wifi,Kitchen,Heating,Essentials,Shampoo,"L...
#
#        availability_30  availability_365  bathrooms  bed_type  bedrooms  beds  \
# 0                    0                77        1.0  Real Bed       1.0   2.0
# 1                    0                 0        1.0  Real Bed       2.0   3.0
# 2                   30               365        4.0  Real Bed       1.0   1.0
# 3                   30               365        4.0  Real Bed       1.0   1.0
# 4                   30                90        1.5  Real Bed       2.0   2.0
# ...                ...               ...        ...       ...       ...   ...
# 88932               28                88        2.0  Real Bed       2.0   4.0
# 88933                0                86        1.0  Real Bed       2.0   2.0
# 88934                0               315        2.5  Real Bed       3.0   2.0
# 88935               16                66        1.0  Real Bed       1.0   1.0
# 88936                0                 8        1.0  Real Bed       1.0   1.0
#
#        calculated_host_listings_count  \
# 0                                   1
# 1                                   1
# 2                                   9
# 3                                   9
# 4                                   2
# ...                               ...
# 88932                               4
# 88933                               3
# 88934                               2
# 88935                               2
# 88936                               1
#
#        calculated_host_listings_count_private_rooms  \
# 0                                               0.0
# 1                                               0.0
# 2                                               9.0
# 3                                               9.0
# 4                                               0.0
# ...                                             ...
# 88932                                           4.0
# 88933                                           1.0
# 88934                                           0.0
# 88935                                           2.0
# 88936                                           1.0
#
#        calculated_host_listings_count_shared_rooms calendar_last_scraped  \
# 0                                              0.0            2019-04-03
# 1                                              0.0            2019-04-03
# 2                                              0.0            2019-04-03
# 3                                              0.0            2019-04-03
# 4                                              0.0            2019-04-03
# ...                                            ...                   ...
# 88932                                          0.0            2019-09-12
# 88933                                          0.0            2019-09-12
# 88934                                          0.0            2019-09-12
# 88935                                          0.0            2019-09-12
# 88936                                          0.0            2019-09-12
#
#       calendar_updated          cancellation_policy           city  \
# 0           a week ago                     moderate  San Francisco
# 1         4 months ago  strict_14_with_grace_period  San Francisco
# 2        17 months ago  strict_14_with_grace_period  San Francisco
# 3        17 months ago  strict_14_with_grace_period  San Francisco
# 4         4 months ago  strict_14_with_grace_period  San Francisco
# ...                ...                          ...            ...
# 88932            today                     flexible      Daly City
# 88933            today                     flexible  San Francisco
# 88934            today                     flexible  San Francisco
# 88935            today  strict_14_with_grace_period  San Francisco
# 88936            today  strict_14_with_grace_period  San Francisco
#
#       cleaning_fee                                        description  \
# 0          $100.00  New update: the house next door is under const...
# 1          $100.00  We live in a large Victorian house on a quiet ...
# 2           $50.00  Nice and good public transportation.  7 minute...
# 3           $50.00  Nice and good public transportation.  7 minute...
# 4          $225.00  Pls email before booking.  Interior featured i...
# ...            ...                                                ...
# 88932       $70.00                                                NaN
# 88933          NaN  2 bedroom apartment in the lively Inner Sunset...
# 88934          NaN  Pitch Perfect 3 Bedroom townhouse apartment st...
# 88935       $40.00  Private Master Suite located in outer Sunset. ...
# 88936       $15.00  Our neighborhood get's pretty the most sunligh...
#
#       extra_people first_review  guests_included  \
# 0           $25.00   2009-07-23                2
# 1            $0.00   2009-05-03                2
# 2           $12.00   2009-08-31                1
# 3           $12.00   2014-09-08                1
# 4          $150.00   2009-09-25                2
# ...            ...          ...              ...
# 88932       $20.00          NaN                4
# 88933        $0.00          NaN                1
# 88934        $0.00          NaN                1
# 88935        $0.00          NaN                1
# 88936        $0.00          NaN                1
#
#                                               host_about host_has_profile_pic  \
# 0      We are a family with 2 boys born in 2009 and 2...                    t
# 1      Philip: English transplant to the Bay Area and...                    t
# 2      7 minutes walk to UCSF.  15 minutes walk to US...                    t
# 3      7 minutes walk to UCSF.  15 minutes walk to US...                    t
# 4      Always searching for a perfect piece at Europe...                    t
# ...                                                  ...                  ...
# 88932                                                NaN                    t
# 88933  I am a retired software engineer,  recently re...                    t
# 88934  I am a 50 year old originally from India and i...                    t
# 88935                                                NaN                    t
# 88936                                                NaN                    t
#
#          host_id host_identity_verified host_is_superhost  \
# 0           1169                      t                 t
# 1           8904                      t                 f
# 2          21994                      t                 f
# 3          21994                      t                 f
# 4          24215                      t                 f
# ...          ...                    ...               ...
# 88932  286256082                      f                 f
# 88933   29536420                      t                 t
# 88934    9536576                      t                 t
# 88935  291879348                      f                 f
# 88936   86582198                      f                 f
#
#        host_listings_count                             host_location  \
# 0                      1.0  San Francisco, California, United States
# 1                      2.0  San Francisco, California, United States
# 2                     10.0  San Francisco, California, United States
# 3                     10.0  San Francisco, California, United States
# 4                      2.0  San Francisco, California, United States
# ...                    ...                                       ...
# 88932                  4.0                                        US
# 88933                  1.0  San Francisco, California, United States
# 88934                  1.0  San Francisco, California, United States
# 88935                  0.0                                        US
# 88936                  2.0  San Francisco, California, United States
#
#               host_name host_neighbourhood  \
# 0                 Holly    Duboce Triangle
# 1      Philip And Tania     Bernal Heights
# 2                 Aaron        Cole Valley
# 3                 Aaron        Cole Valley
# 4                  Rosy       Alamo Square
# ...                 ...                ...
# 88932           Francis     Crocker Amazon
# 88933           Claudia       Inner Sunset
# 88934               Raj    Pacific Heights
# 88935             Jason       Outer Sunset
# 88936             Nitch            Bayview
#
#                                         host_picture_url host_response_rate  \
# 0      https://a0.muscache.com/im/pictures/efdad96a-3...               100%
# 1      https://a0.muscache.com/im/users/8904/profile_...                80%
# 2      https://a0.muscache.com/im/users/21994/profile...               100%
# 3      https://a0.muscache.com/im/users/21994/profile...               100%
# 4      https://a0.muscache.com/im/users/24215/profile...               100%
# ...                                                  ...                ...
# 88932  https://a0.muscache.com/im/pictures/user/15d11...               100%
# 88933  https://a0.muscache.com/im/users/29536420/prof...               100%
# 88934  https://a0.muscache.com/im/users/9536576/profi...               100%
# 88935  https://a0.muscache.com/im/pictures/user/cca19...                NaN
# 88936  https://a0.muscache.com/im/pictures/user/90847...                NaN
#
#        host_response_time  host_since  \
# 0          within an hour  2008-07-31
# 1            within a day  2009-03-02
# 2      within a few hours  2009-06-17
# 3      within a few hours  2009-06-17
# 4          within an hour  2009-07-02
# ...                   ...         ...
# 88932      within an hour  2019-08-16
# 88933      within an hour  2015-03-17
# 88934      within an hour  2013-10-20
# 88935                 NaN  2019-09-04
# 88936                 NaN  2016-07-28
#
#                                       host_thumbnail_url  \
# 0      https://a0.muscache.com/im/pictures/efdad96a-3...
# 1      https://a0.muscache.com/im/users/8904/profile_...
# 2      https://a0.muscache.com/im/users/21994/profile...
# 3      https://a0.muscache.com/im/users/21994/profile...
# 4      https://a0.muscache.com/im/users/24215/profile...
# ...                                                  ...
# 88932  https://a0.muscache.com/im/pictures/user/15d11...
# 88933  https://a0.muscache.com/im/users/29536420/prof...
# 88934  https://a0.muscache.com/im/users/9536576/profi...
# 88935  https://a0.muscache.com/im/pictures/user/cca19...
# 88936  https://a0.muscache.com/im/pictures/user/90847...
#
#                                           host_url  \
# 0           https://www.airbnb.com/users/show/1169
# 1           https://www.airbnb.com/users/show/8904
# 2          https://www.airbnb.com/users/show/21994
# 3          https://www.airbnb.com/users/show/21994
# 4          https://www.airbnb.com/users/show/24215
# ...                                            ...
# 88932  https://www.airbnb.com/users/show/286256082
# 88933   https://www.airbnb.com/users/show/29536420
# 88934    https://www.airbnb.com/users/show/9536576
# 88935  https://www.airbnb.com/users/show/291879348
# 88936   https://www.airbnb.com/users/show/86582198
#
#                                       host_verifications  \
# 0       ['email', 'phone', 'facebook', 'reviews', 'kba']
# 1      ['email', 'phone', 'reviews', 'kba', 'work_ema...
# 2      ['email', 'phone', 'reviews', 'jumio', 'govern...
# 3      ['email', 'phone', 'reviews', 'jumio', 'govern...
# 4                   ['email', 'phone', 'reviews', 'kba']
# ...                                                  ...
# 88932  ['email', 'phone', 'offline_government_id', 's...
# 88933  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 88934               ['email', 'phone', 'reviews', 'kba']
# 88935  ['phone', 'offline_government_id', 'government...
# 88936  ['email', 'phone', 'jumio', 'offline_governmen...
#
#                                              house_rules        id  \
# 0      * No Pets - even visiting guests for a short t...       958
# 1      Please respect the house, the art work, the fu...      5858
# 2      No party, No smoking, not for any kinds of smo...      7918
# 3           no pet no smoke no party inside the building      8142
# 4      House Manual and House Rules will be provided ...      8339
# ...                                                  ...       ...
# 88932                            Quiet hours: 10pm - 8am  38533186
# 88933                                                NaN  38544501
# 88934                                                NaN  38550921
# 88935  Quiet hour after 10pm Please do not invite oth...  38556299
# 88936                                                NaN  38557230
#
#       instant_bookable is_location_exact last_review  latitude  \
# 0                    t                 t  2019-03-16  37.76931
# 1                    f                 t  2017-08-06  37.74511
# 2                    f                 t  2016-11-21  37.76669
# 3                    f                 t  2018-09-12  37.76487
# 4                    f                 t  2018-08-11  37.77525
# ...                ...               ...         ...       ...
# 88932                f                 t         NaN  37.70707
# 88933                t                 t         NaN  37.76324
# 88934                t                 t         NaN  37.79199
# 88935                t                 t         NaN  37.74284
# 88936                t                 t         NaN  37.72189
#
#                                  listing_url  longitude  \
# 0           https://www.airbnb.com/rooms/958 -122.43386
# 1          https://www.airbnb.com/rooms/5858 -122.42102
# 2          https://www.airbnb.com/rooms/7918 -122.45250
# 3          https://www.airbnb.com/rooms/8142 -122.45183
# 4          https://www.airbnb.com/rooms/8339 -122.43637
# ...                                      ...        ...
# 88932  https://www.airbnb.com/rooms/38533186 -122.44812
# 88933  https://www.airbnb.com/rooms/38544501 -122.47466
# 88934  https://www.airbnb.com/rooms/38550921 -122.44106
# 88935  https://www.airbnb.com/rooms/38556299 -122.49925
# 88936  https://www.airbnb.com/rooms/38557230 -122.39304
#
#        maximum_maximum_nights  \
# 0                        30.0
# 1                        60.0
# 2                        60.0
# 3                        90.0
# 4                      1125.0
# ...                       ...
# 88932                    29.0
# 88933                  1125.0
# 88934                  1125.0
# 88935                  1125.0
# 88936                    10.0
#
#                                                     name  \
# 0                    Bright, Modern Garden Unit - 1BR/1B
# 1                                     Creative Sanctuary
# 2             A Friendly Room - UCSF/USF - San Francisco
# 3      Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                        Historic Alamo Square Victorian
# ...                                                  ...
# 88932    !159D 2B1B newly renovated quiet unit w/parking
# 88933                        Inner Sunset Monthly rental
# 88934  Designer 3BR, 2.5 bath SF Apartment in Pac Hei...
# 88935      Private Master bedroom w/ private bathroom -1
# 88936                Bright and Spacious Room in Bayview
#
#                                    neighborhood_overview  \
# 0      *Quiet cul de sac in friendly neighborhood *St...
# 1      I love how our neighborhood feels quiet but is...
# 2      Shopping old town, restaurants, McDonald, Whol...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 88932                                                NaN
# 88933  Many great Asian restaurants & shops including...
# 88934  * Close to Alta Plaza Park * Walking distance ...
# 88935                       Safe and quiet neighborhood.
# 88936  As stated before we have transportation such a...
#
#       neighbourhood_cleansed  number_of_reviews  number_of_reviews_ltm  \
# 0           Western Addition                183                   51.0
# 1             Bernal Heights                111                    0.0
# 2             Haight Ashbury                 17                    0.0
# 3             Haight Ashbury                  8                    1.0
# 4           Western Addition                 27                    1.0
# ...                      ...                ...                    ...
# 88932         Crocker Amazon                  0                    0.0
# 88933           Inner Sunset                  0                    0.0
# 88934        Pacific Heights                  0                    0.0
# 88935               Parkside                  0                    0.0
# 88936                Bayview                  0                    0.0
#
#                                              picture_url    price  \
# 0      https://a0.muscache.com/im/pictures/b7c2a199-4...  $170.00
# 1      https://a0.muscache.com/im/pictures/17714/3a7a...  $235.00
# 2      https://a0.muscache.com/im/pictures/26356/8030...   $65.00
# 3      https://a0.muscache.com/im/pictures/27832/3b1f...   $65.00
# 4      https://a0.muscache.com/im/pictures/6f84a7c2-e...  $785.00
# ...                                                  ...      ...
# 88932  https://a0.muscache.com/im/pictures/38cf6009-b...  $150.00
# 88933  https://a0.muscache.com/im/pictures/d9926f9a-9...  $125.00
# 88934  https://a0.muscache.com/im/pictures/80c82053-1...  $450.00
# 88935  https://a0.muscache.com/im/pictures/95233473-5...   $75.00
# 88936  https://a0.muscache.com/im/pictures/eecb12ff-3...   $55.00
#
#       property_type require_guest_phone_verification  \
# 0         Apartment                                f
# 1         Apartment                                f
# 2         Apartment                                f
# 3         Apartment                                f
# 4             House                                t
# ...             ...                              ...
# 88932         House                                f
# 88933     Apartment                                f
# 88934     Apartment                                f
# 88935         House                                f
# 88936         House                                f
#
#       require_guest_profile_picture requires_license  review_scores_accuracy  \
# 0                                 f                t                    10.0
# 1                                 f                t                    10.0
# 2                                 f                t                     8.0
# 3                                 f                t                     9.0
# 4                                 t                t                    10.0
# ...                             ...              ...                     ...
# 88932                             f                f                     NaN
# 88933                             f                t                     NaN
# 88934                             f                t                     NaN
# 88935                             f                t                     NaN
# 88936                             f                t                     NaN
#
#        review_scores_checkin  review_scores_cleanliness  \
# 0                       10.0                       10.0
# 1                       10.0                       10.0
# 2                        9.0                        8.0
# 3                       10.0                        9.0
# 4                       10.0                       10.0
# ...                      ...                        ...
# 88932                    NaN                        NaN
# 88933                    NaN                        NaN
# 88934                    NaN                        NaN
# 88935                    NaN                        NaN
# 88936                    NaN                        NaN
#
#        review_scores_communication  review_scores_location  \
# 0                             10.0                    10.0
# 1                             10.0                    10.0
# 2                              9.0                     9.0
# 3                             10.0                     9.0
# 4                             10.0                    10.0
# ...                            ...                     ...
# 88932                          NaN                     NaN
# 88933                          NaN                     NaN
# 88934                          NaN                     NaN
# 88935                          NaN                     NaN
# 88936                          NaN                     NaN
#
#        review_scores_rating  review_scores_value  reviews_per_month  \
# 0                      97.0                 10.0               1.55
# 1                      98.0                  9.0               0.92
# 2                      85.0                  8.0               0.15
# 3                      93.0                  9.0               0.14
# 4                      97.0                  9.0               0.23
# ...                     ...                  ...                ...
# 88932                   NaN                  NaN                NaN
# 88933                   NaN                  NaN                NaN
# 88934                   NaN                  NaN                NaN
# 88935                   NaN                  NaN                NaN
# 88936                   NaN                  NaN                NaN
#
#              room_type     scrape_id security_deposit  \
# 0      Entire home/apt  2.019040e+13          $100.00
# 1      Entire home/apt  2.019040e+13              NaN
# 2         Private room  2.019040e+13          $200.00
# 3         Private room  2.019040e+13          $200.00
# 4      Entire home/apt  2.019040e+13            $0.00
# ...                ...           ...              ...
# 88932     Private room  2.019091e+13          $100.00
# 88933  Entire home/apt  2.019091e+13              NaN
# 88934  Entire home/apt  2.019091e+13              NaN
# 88935     Private room  2.019091e+13            $0.00
# 88936     Private room  2.019091e+13            $0.00
#
#                                                    space  \
# 0      Newly remodeled, modern, and bright garden uni...
# 1      We live in a large Victorian house on a quiet ...
# 2      Room rental-sunny view room/sink/Wi Fi (inner ...
# 3      Room rental Sunny view Rm/Wi-Fi/TV/sink/large ...
# 4      Please send us a quick message before booking ...
# ...                                                  ...
# 88932                                                NaN
# 88933  There are a washer and dryer in the closet for...
# 88934  The first level consists of formal living and ...
# 88935  This is a share environment,please be aware th...
# 88936  The bedroom is equipped with one full size bed...
#
#                                                  summary  \
# 0      New update: the house next door is under const...
# 1                                                    NaN
# 2      Nice and good public transportation.  7 minute...
# 3      Nice and good public transportation.  7 minute...
# 4      Pls email before booking.  Interior featured i...
# ...                                                  ...
# 88932                                                NaN
# 88933  2 bedroom apartment in the lively Inner Sunset...
# 88934  Pitch Perfect 3 Bedroom townhouse apartment st...
# 88935  Private Master Suite located in outer Sunset. ...
# 88936  Our neighborhood get's pretty the most sunligh...
#
#                                                  transit zipcode weekly_price  \
# 0      *Public Transportation is 1/2 block away.  *Ce...   94117    $1,120.00
# 1      The train is two blocks away and you can stop ...   94110    $1,600.00
# 2             N Juda Muni and bus stop.  Street parking.   94117      $485.00
# 3      N Juda Muni, Bus and UCSF Shuttle. small shopp...   94117      $490.00
# 4                                                    NaN   94117          NaN
# ...                                                  ...     ...          ...
# 88932                                                NaN   94014          NaN
# 88933  The N-Judah stops at 16th & Judah (15th going ...   94122          NaN
# 88934                   * Bus transportation is close by   94115          NaN
# 88935                                    Bus, Uber, Lyft   94116          NaN
# 88936  Getting around SF.  Driving/Uber: takes about ...   94124          NaN
#
#       monthly_price
# 0         $4,200.00
# 1         $5,500.00
# 2         $1,685.00
# 3         $1,685.00
# 4               NaN
# ...             ...
# 88932           NaN
# 88933           NaN
# 88934           NaN
# 88935           NaN
# 88936           NaN
#
# [88937 rows x 73 columns]

# %%
listings
# Out:
#        accommodates                                          amenities  \
# 0                 3  {TV,"Cable TV",Internet,Wifi,Kitchen,"Pets liv...
# 1                 5  {Internet,Wifi,Kitchen,Heating,"Family/kid fri...
# 2                 2  {TV,Internet,Wifi,Kitchen,"Free street parking...
# 3                 2  {TV,Internet,Wifi,Kitchen,"Free street parking...
# 4                 5  {TV,Internet,Wifi,Kitchen,Heating,"Family/kid ...
# ...             ...                                                ...
# 88932             5  {TV,Wifi,"Free parking on premises","Free stre...
# 88933             4  {TV,Internet,Wifi,Kitchen,"Free street parking...
# 88934             4  {TV,Wifi,Kitchen,"Free parking on premises","P...
# 88935             2  {Wifi,"Smoke detector","Carbon monoxide detect...
# 88936             2  {TV,Wifi,Kitchen,Heating,Essentials,Shampoo,"L...
#
#        availability_30  availability_365  bathrooms  bed_type  bedrooms  beds  \
# 0                    0                77        1.0  Real Bed       1.0   2.0
# 1                    0                 0        1.0  Real Bed       2.0   3.0
# 2                   30               365        4.0  Real Bed       1.0   1.0
# 3                   30               365        4.0  Real Bed       1.0   1.0
# 4                   30                90        1.5  Real Bed       2.0   2.0
# ...                ...               ...        ...       ...       ...   ...
# 88932               28                88        2.0  Real Bed       2.0   4.0
# 88933                0                86        1.0  Real Bed       2.0   2.0
# 88934                0               315        2.5  Real Bed       3.0   2.0
# 88935               16                66        1.0  Real Bed       1.0   1.0
# 88936                0                 8        1.0  Real Bed       1.0   1.0
#
#        calculated_host_listings_count  \
# 0                                   1
# 1                                   1
# 2                                   9
# 3                                   9
# 4                                   2
# ...                               ...
# 88932                               4
# 88933                               3
# 88934                               2
# 88935                               2
# 88936                               1
#
#        calculated_host_listings_count_private_rooms  \
# 0                                               0.0
# 1                                               0.0
# 2                                               9.0
# 3                                               9.0
# 4                                               0.0
# ...                                             ...
# 88932                                           4.0
# 88933                                           1.0
# 88934                                           0.0
# 88935                                           2.0
# 88936                                           1.0
#
#        calculated_host_listings_count_shared_rooms calendar_last_scraped  \
# 0                                              0.0            2019-04-03
# 1                                              0.0            2019-04-03
# 2                                              0.0            2019-04-03
# 3                                              0.0            2019-04-03
# 4                                              0.0            2019-04-03
# ...                                            ...                   ...
# 88932                                          0.0            2019-09-12
# 88933                                          0.0            2019-09-12
# 88934                                          0.0            2019-09-12
# 88935                                          0.0            2019-09-12
# 88936                                          0.0            2019-09-12
#
#       calendar_updated          cancellation_policy           city  \
# 0           a week ago                     moderate  San Francisco
# 1         4 months ago  strict_14_with_grace_period  San Francisco
# 2        17 months ago  strict_14_with_grace_period  San Francisco
# 3        17 months ago  strict_14_with_grace_period  San Francisco
# 4         4 months ago  strict_14_with_grace_period  San Francisco
# ...                ...                          ...            ...
# 88932            today                     flexible      Daly City
# 88933            today                     flexible  San Francisco
# 88934            today                     flexible  San Francisco
# 88935            today  strict_14_with_grace_period  San Francisco
# 88936            today  strict_14_with_grace_period  San Francisco
#
#       cleaning_fee                                        description  \
# 0          $100.00  New update: the house next door is under const...
# 1          $100.00  We live in a large Victorian house on a quiet ...
# 2           $50.00  Nice and good public transportation.  7 minute...
# 3           $50.00  Nice and good public transportation.  7 minute...
# 4          $225.00  Pls email before booking.  Interior featured i...
# ...            ...                                                ...
# 88932       $70.00                                                NaN
# 88933          NaN  2 bedroom apartment in the lively Inner Sunset...
# 88934          NaN  Pitch Perfect 3 Bedroom townhouse apartment st...
# 88935       $40.00  Private Master Suite located in outer Sunset. ...
# 88936       $15.00  Our neighborhood get's pretty the most sunligh...
#
#       extra_people first_review  guests_included  \
# 0           $25.00   2009-07-23                2
# 1            $0.00   2009-05-03                2
# 2           $12.00   2009-08-31                1
# 3           $12.00   2014-09-08                1
# 4          $150.00   2009-09-25                2
# ...            ...          ...              ...
# 88932       $20.00          NaN                4
# 88933        $0.00          NaN                1
# 88934        $0.00          NaN                1
# 88935        $0.00          NaN                1
# 88936        $0.00          NaN                1
#
#                                               host_about host_has_profile_pic  \
# 0      We are a family with 2 boys born in 2009 and 2...                    t
# 1      Philip: English transplant to the Bay Area and...                    t
# 2      7 minutes walk to UCSF.  15 minutes walk to US...                    t
# 3      7 minutes walk to UCSF.  15 minutes walk to US...                    t
# 4      Always searching for a perfect piece at Europe...                    t
# ...                                                  ...                  ...
# 88932                                                NaN                    t
# 88933  I am a retired software engineer,  recently re...                    t
# 88934  I am a 50 year old originally from India and i...                    t
# 88935                                                NaN                    t
# 88936                                                NaN                    t
#
#          host_id host_identity_verified host_is_superhost  \
# 0           1169                      t                 t
# 1           8904                      t                 f
# 2          21994                      t                 f
# 3          21994                      t                 f
# 4          24215                      t                 f
# ...          ...                    ...               ...
# 88932  286256082                      f                 f
# 88933   29536420                      t                 t
# 88934    9536576                      t                 t
# 88935  291879348                      f                 f
# 88936   86582198                      f                 f
#
#        host_listings_count                             host_location  \
# 0                      1.0  San Francisco, California, United States
# 1                      2.0  San Francisco, California, United States
# 2                     10.0  San Francisco, California, United States
# 3                     10.0  San Francisco, California, United States
# 4                      2.0  San Francisco, California, United States
# ...                    ...                                       ...
# 88932                  4.0                                        US
# 88933                  1.0  San Francisco, California, United States
# 88934                  1.0  San Francisco, California, United States
# 88935                  0.0                                        US
# 88936                  2.0  San Francisco, California, United States
#
#               host_name host_neighbourhood  \
# 0                 Holly    Duboce Triangle
# 1      Philip And Tania     Bernal Heights
# 2                 Aaron        Cole Valley
# 3                 Aaron        Cole Valley
# 4                  Rosy       Alamo Square
# ...                 ...                ...
# 88932           Francis     Crocker Amazon
# 88933           Claudia       Inner Sunset
# 88934               Raj    Pacific Heights
# 88935             Jason       Outer Sunset
# 88936             Nitch            Bayview
#
#                                         host_picture_url host_response_rate  \
# 0      https://a0.muscache.com/im/pictures/efdad96a-3...               100%
# 1      https://a0.muscache.com/im/users/8904/profile_...                80%
# 2      https://a0.muscache.com/im/users/21994/profile...               100%
# 3      https://a0.muscache.com/im/users/21994/profile...               100%
# 4      https://a0.muscache.com/im/users/24215/profile...               100%
# ...                                                  ...                ...
# 88932  https://a0.muscache.com/im/pictures/user/15d11...               100%
# 88933  https://a0.muscache.com/im/users/29536420/prof...               100%
# 88934  https://a0.muscache.com/im/users/9536576/profi...               100%
# 88935  https://a0.muscache.com/im/pictures/user/cca19...                NaN
# 88936  https://a0.muscache.com/im/pictures/user/90847...                NaN
#
#        host_response_time  host_since  \
# 0          within an hour  2008-07-31
# 1            within a day  2009-03-02
# 2      within a few hours  2009-06-17
# 3      within a few hours  2009-06-17
# 4          within an hour  2009-07-02
# ...                   ...         ...
# 88932      within an hour  2019-08-16
# 88933      within an hour  2015-03-17
# 88934      within an hour  2013-10-20
# 88935                 NaN  2019-09-04
# 88936                 NaN  2016-07-28
#
#                                       host_thumbnail_url  \
# 0      https://a0.muscache.com/im/pictures/efdad96a-3...
# 1      https://a0.muscache.com/im/users/8904/profile_...
# 2      https://a0.muscache.com/im/users/21994/profile...
# 3      https://a0.muscache.com/im/users/21994/profile...
# 4      https://a0.muscache.com/im/users/24215/profile...
# ...                                                  ...
# 88932  https://a0.muscache.com/im/pictures/user/15d11...
# 88933  https://a0.muscache.com/im/users/29536420/prof...
# 88934  https://a0.muscache.com/im/users/9536576/profi...
# 88935  https://a0.muscache.com/im/pictures/user/cca19...
# 88936  https://a0.muscache.com/im/pictures/user/90847...
#
#                                           host_url  \
# 0           https://www.airbnb.com/users/show/1169
# 1           https://www.airbnb.com/users/show/8904
# 2          https://www.airbnb.com/users/show/21994
# 3          https://www.airbnb.com/users/show/21994
# 4          https://www.airbnb.com/users/show/24215
# ...                                            ...
# 88932  https://www.airbnb.com/users/show/286256082
# 88933   https://www.airbnb.com/users/show/29536420
# 88934    https://www.airbnb.com/users/show/9536576
# 88935  https://www.airbnb.com/users/show/291879348
# 88936   https://www.airbnb.com/users/show/86582198
#
#                                       host_verifications  \
# 0       ['email', 'phone', 'facebook', 'reviews', 'kba']
# 1      ['email', 'phone', 'reviews', 'kba', 'work_ema...
# 2      ['email', 'phone', 'reviews', 'jumio', 'govern...
# 3      ['email', 'phone', 'reviews', 'jumio', 'govern...
# 4                   ['email', 'phone', 'reviews', 'kba']
# ...                                                  ...
# 88932  ['email', 'phone', 'offline_government_id', 's...
# 88933  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 88934               ['email', 'phone', 'reviews', 'kba']
# 88935  ['phone', 'offline_government_id', 'government...
# 88936  ['email', 'phone', 'jumio', 'offline_governmen...
#
#                                              house_rules        id  \
# 0      * No Pets - even visiting guests for a short t...       958
# 1      Please respect the house, the art work, the fu...      5858
# 2      No party, No smoking, not for any kinds of smo...      7918
# 3           no pet no smoke no party inside the building      8142
# 4      House Manual and House Rules will be provided ...      8339
# ...                                                  ...       ...
# 88932                            Quiet hours: 10pm - 8am  38533186
# 88933                                                NaN  38544501
# 88934                                                NaN  38550921
# 88935  Quiet hour after 10pm Please do not invite oth...  38556299
# 88936                                                NaN  38557230
#
#       instant_bookable is_location_exact last_review  latitude  \
# 0                    t                 t  2019-03-16  37.76931
# 1                    f                 t  2017-08-06  37.74511
# 2                    f                 t  2016-11-21  37.76669
# 3                    f                 t  2018-09-12  37.76487
# 4                    f                 t  2018-08-11  37.77525
# ...                ...               ...         ...       ...
# 88932                f                 t         NaN  37.70707
# 88933                t                 t         NaN  37.76324
# 88934                t                 t         NaN  37.79199
# 88935                t                 t         NaN  37.74284
# 88936                t                 t         NaN  37.72189
#
#                                  listing_url  longitude  \
# 0           https://www.airbnb.com/rooms/958 -122.43386
# 1          https://www.airbnb.com/rooms/5858 -122.42102
# 2          https://www.airbnb.com/rooms/7918 -122.45250
# 3          https://www.airbnb.com/rooms/8142 -122.45183
# 4          https://www.airbnb.com/rooms/8339 -122.43637
# ...                                      ...        ...
# 88932  https://www.airbnb.com/rooms/38533186 -122.44812
# 88933  https://www.airbnb.com/rooms/38544501 -122.47466
# 88934  https://www.airbnb.com/rooms/38550921 -122.44106
# 88935  https://www.airbnb.com/rooms/38556299 -122.49925
# 88936  https://www.airbnb.com/rooms/38557230 -122.39304
#
#        maximum_maximum_nights  \
# 0                        30.0
# 1                        60.0
# 2                        60.0
# 3                        90.0
# 4                      1125.0
# ...                       ...
# 88932                    29.0
# 88933                  1125.0
# 88934                  1125.0
# 88935                  1125.0
# 88936                    10.0
#
#                                                     name  \
# 0                    Bright, Modern Garden Unit - 1BR/1B
# 1                                     Creative Sanctuary
# 2             A Friendly Room - UCSF/USF - San Francisco
# 3      Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                        Historic Alamo Square Victorian
# ...                                                  ...
# 88932    !159D 2B1B newly renovated quiet unit w/parking
# 88933                        Inner Sunset Monthly rental
# 88934  Designer 3BR, 2.5 bath SF Apartment in Pac Hei...
# 88935      Private Master bedroom w/ private bathroom -1
# 88936                Bright and Spacious Room in Bayview
#
#                                    neighborhood_overview  \
# 0      *Quiet cul de sac in friendly neighborhood *St...
# 1      I love how our neighborhood feels quiet but is...
# 2      Shopping old town, restaurants, McDonald, Whol...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 88932                                                NaN
# 88933  Many great Asian restaurants & shops including...
# 88934  * Close to Alta Plaza Park * Walking distance ...
# 88935                       Safe and quiet neighborhood.
# 88936  As stated before we have transportation such a...
#
#       neighbourhood_cleansed  number_of_reviews  number_of_reviews_ltm  \
# 0           Western Addition                183                   51.0
# 1             Bernal Heights                111                    0.0
# 2             Haight Ashbury                 17                    0.0
# 3             Haight Ashbury                  8                    1.0
# 4           Western Addition                 27                    1.0
# ...                      ...                ...                    ...
# 88932         Crocker Amazon                  0                    0.0
# 88933           Inner Sunset                  0                    0.0
# 88934        Pacific Heights                  0                    0.0
# 88935               Parkside                  0                    0.0
# 88936                Bayview                  0                    0.0
#
#                                              picture_url    price  \
# 0      https://a0.muscache.com/im/pictures/b7c2a199-4...  $170.00
# 1      https://a0.muscache.com/im/pictures/17714/3a7a...  $235.00
# 2      https://a0.muscache.com/im/pictures/26356/8030...   $65.00
# 3      https://a0.muscache.com/im/pictures/27832/3b1f...   $65.00
# 4      https://a0.muscache.com/im/pictures/6f84a7c2-e...  $785.00
# ...                                                  ...      ...
# 88932  https://a0.muscache.com/im/pictures/38cf6009-b...  $150.00
# 88933  https://a0.muscache.com/im/pictures/d9926f9a-9...  $125.00
# 88934  https://a0.muscache.com/im/pictures/80c82053-1...  $450.00
# 88935  https://a0.muscache.com/im/pictures/95233473-5...   $75.00
# 88936  https://a0.muscache.com/im/pictures/eecb12ff-3...   $55.00
#
#       property_type require_guest_phone_verification  \
# 0         Apartment                                f
# 1         Apartment                                f
# 2         Apartment                                f
# 3         Apartment                                f
# 4             House                                t
# ...             ...                              ...
# 88932         House                                f
# 88933     Apartment                                f
# 88934     Apartment                                f
# 88935         House                                f
# 88936         House                                f
#
#       require_guest_profile_picture requires_license  review_scores_accuracy  \
# 0                                 f                t                    10.0
# 1                                 f                t                    10.0
# 2                                 f                t                     8.0
# 3                                 f                t                     9.0
# 4                                 t                t                    10.0
# ...                             ...              ...                     ...
# 88932                             f                f                     NaN
# 88933                             f                t                     NaN
# 88934                             f                t                     NaN
# 88935                             f                t                     NaN
# 88936                             f                t                     NaN
#
#        review_scores_checkin  review_scores_cleanliness  \
# 0                       10.0                       10.0
# 1                       10.0                       10.0
# 2                        9.0                        8.0
# 3                       10.0                        9.0
# 4                       10.0                       10.0
# ...                      ...                        ...
# 88932                    NaN                        NaN
# 88933                    NaN                        NaN
# 88934                    NaN                        NaN
# 88935                    NaN                        NaN
# 88936                    NaN                        NaN
#
#        review_scores_communication  review_scores_location  \
# 0                             10.0                    10.0
# 1                             10.0                    10.0
# 2                              9.0                     9.0
# 3                             10.0                     9.0
# 4                             10.0                    10.0
# ...                            ...                     ...
# 88932                          NaN                     NaN
# 88933                          NaN                     NaN
# 88934                          NaN                     NaN
# 88935                          NaN                     NaN
# 88936                          NaN                     NaN
#
#        review_scores_rating  review_scores_value  reviews_per_month  \
# 0                      97.0                 10.0               1.55
# 1                      98.0                  9.0               0.92
# 2                      85.0                  8.0               0.15
# 3                      93.0                  9.0               0.14
# 4                      97.0                  9.0               0.23
# ...                     ...                  ...                ...
# 88932                   NaN                  NaN                NaN
# 88933                   NaN                  NaN                NaN
# 88934                   NaN                  NaN                NaN
# 88935                   NaN                  NaN                NaN
# 88936                   NaN                  NaN                NaN
#
#              room_type     scrape_id security_deposit  \
# 0      Entire home/apt  2.019040e+13          $100.00
# 1      Entire home/apt  2.019040e+13              NaN
# 2         Private room  2.019040e+13          $200.00
# 3         Private room  2.019040e+13          $200.00
# 4      Entire home/apt  2.019040e+13            $0.00
# ...                ...           ...              ...
# 88932     Private room  2.019091e+13          $100.00
# 88933  Entire home/apt  2.019091e+13              NaN
# 88934  Entire home/apt  2.019091e+13              NaN
# 88935     Private room  2.019091e+13            $0.00
# 88936     Private room  2.019091e+13            $0.00
#
#                                                    space  \
# 0      Newly remodeled, modern, and bright garden uni...
# 1      We live in a large Victorian house on a quiet ...
# 2      Room rental-sunny view room/sink/Wi Fi (inner ...
# 3      Room rental Sunny view Rm/Wi-Fi/TV/sink/large ...
# 4      Please send us a quick message before booking ...
# ...                                                  ...
# 88932                                                NaN
# 88933  There are a washer and dryer in the closet for...
# 88934  The first level consists of formal living and ...
# 88935  This is a share environment,please be aware th...
# 88936  The bedroom is equipped with one full size bed...
#
#                                                  summary  \
# 0      New update: the house next door is under const...
# 1                                                    NaN
# 2      Nice and good public transportation.  7 minute...
# 3      Nice and good public transportation.  7 minute...
# 4      Pls email before booking.  Interior featured i...
# ...                                                  ...
# 88932                                                NaN
# 88933  2 bedroom apartment in the lively Inner Sunset...
# 88934  Pitch Perfect 3 Bedroom townhouse apartment st...
# 88935  Private Master Suite located in outer Sunset. ...
# 88936  Our neighborhood get's pretty the most sunligh...
#
#                                                  transit zipcode
# 0      *Public Transportation is 1/2 block away.  *Ce...   94117
# 1      The train is two blocks away and you can stop ...   94110
# 2             N Juda Muni and bus stop.  Street parking.   94117
# 3      N Juda Muni, Bus and UCSF Shuttle. small shopp...   94117
# 4                                                    NaN   94117
# ...                                                  ...     ...
# 88932                                                NaN   94014
# 88933  The N-Judah stops at 16th & Judah (15th going ...   94122
# 88934                   * Bus transportation is close by   94115
# 88935                                    Bus, Uber, Lyft   94116
# 88936  Getting around SF.  Driving/Uber: takes about ...   94124
#
# [88937 rows x 71 columns]

# %% [markdown]
# **Removing columns containing URL data**
#
# URL columns contain only url link to images, which is not pertinent to our analysis.

# %%
#Drop columns containing URL's
listings = listings[listings.columns.drop(list(listings.filter(regex='url$')))]

#Updated listings shape
print('Updated listings shape:', listings.shape)

# %% [markdown]
# ### Column Specific Cleaning
#
# Cleaning specific columns in listings data in which there were specific value issues spotted in the Pandas Profiling report.

# %% [raw]
# **String Formatting**

# %%
#Create list of cols that contain $%,{}[]"'
cols = ['cleaning_fee','extra_people','price','host_response_rate','security_deposit',
        'host_verifications','amenities']

#Remove $%,{}[]"'
listings[cols] = listings[cols].replace('[$,%{}\"\'\[\]]', ' ', regex=True)

#Remove white space between numerics
listings[cols] = listings[cols].replace('(?<=\d)\s+(?=\d)', '', regex=True)

#Check
listings[cols].head(3)

# %% [markdown]
# **Mapping 1's and 0's to Booleans**
#
# There are several columns that contain strings 't' and 'f' to signify True and False. I will be updating these strings with the appropriate boolean values.

# %%
#List of columns to convert t's to 1's and f's to 0's
cols = ['host_has_profile_pic', 'host_identity_verified', 'host_is_superhost','instant_bookable','is_location_exact',
       'require_guest_phone_verification','require_guest_profile_picture','requires_license']

#Create dictionary to map True and False
mymap = {'t':True, 'f':False}

#Replace t's and f's with 1 and 0
listings[cols]=listings[cols].applymap(lambda s: mymap.get(s) if s in mymap else s)

#Fill missing values with a False
listings[cols] = listings[cols].fillna(0)

#Check
listings[cols].head(3)

# %% [markdown]
# **City Column**

# %%
#Replace neighborhood information with San Fancisco
listings.city.replace('^(?!South|D|V|Br|Ba|Nor).*', 'San Francisco', regex=True, inplace=True)

#Create list of outliers
outliers = ['Bay Area', 'Nor cal', 'Vallejo']

#Investigate rows with these outlier cities
listings[listings.city.isin(outliers)]

# %% [markdown]
# Outlier properties are SF properties. Updating city column

# %%
#Update city column
listings.city[listings.city.isin(outliers)]= 'San Francisco'

#Strip white space
listings.city = listings.city.str.strip()

#Check city values
listings.groupby('city')['city'].count()

# %% [markdown]
# **Miscellaneous column cleaning**

# %%
#convert 'a week ago' to '1 week ago' in calendar_updated
listings['calendar_updated'].replace('a week ago', '1 week ago', inplace=True)

# %% [markdown]
# **Zipcode**

# %%
import os

os.environ["GOOGLE_API_KEY"] = "AIzaSyAxsYeHC9EVsnvV7eiqto8JkwT43cXJm3g"
import geocoder

reverse = geocoder.google([37.727920, -122.440290], method = 'reverse', key = 'AIzaSyAxsYeHC9EVsnvV7eiqto8JkwT43cXJm3g')

print('San Francisco, California', reverse.city)

# %%
#Capture lat and long of rows with CA as the zipcode. 
print(listings[['latitude', 'longitude', 'zipcode']][listings.zipcode =='CA'])

#Per lat/long, zip = 94112. Updating 
listings.zipcode[listings.zipcode =='CA'] = 94112

# %%
#Remove trailing 0's
listings['zipcode'] = listings['zipcode'].replace('\.0$', '', regex=True)

#Remove CA\s from zipcode
listings.zipcode.replace('CA\s','',inplace = True, regex=True)

# %% [markdown]
# ### Missing Values

# %%
#Total data points available
total = listings.notna().sum().sort_values(ascending=True)

#Capture total number of missing data per column
total_missing = listings.isna().sum().sort_values(ascending=False)

#Calculate the % of missing data per column
percent = (listings.isnull().sum()/listings.isnull().count()).sort_values(ascending=False)


#Concatenate into a pd dataframe
missing_data = pd.concat([total, total_missing, percent], axis=1, keys=['Total','Missing', 'Missing %'])

#Format percentage  
missing_data['Missing %'] = missing_data['Missing %'].apply(lambda x: x * 100)

#Sort missing_data by Missing Percent
missing_data= missing_data.sort_values(by = 'Missing %', ascending=False)

#View columns with data missing
missing_data.loc[missing_data['Missing %'] > 0]

# %% [markdown]
# At this time, I will leave the data as is. We have a lot of rows to build a model from.

# %% [markdown]
# ### Data Type Conversion

# %%
listings.dtypes

#Need to be numeric (int64)
cleaning_fee, extra_people, host_response_rate                              

#Need to be date
calendar_last_scraped, calendar_updated, first_review  

#/need to be bool
host_has_profile_pic, host_identity_verified, host_is_superhost

# %% [markdown]
# **Format boolean columns**

# %%
#Converting boolean columns to int8
cols = ['host_has_profile_pic', 'host_identity_verified', 'host_is_superhost','instant_bookable','is_location_exact',
       'require_guest_phone_verification','require_guest_profile_picture','requires_license']

#Convert cols to int 8 to save memory and check
listings[cols] = listings[cols].astype('int8', errors='ignore')

#check
listings[cols].dtypes

# %% [markdown]
# **Format date columns**

# %%
#List of columns to convert to dates
cols = ['calendar_last_scraped','first_review', 'host_since', 'last_review']

#Convert cols to date time
listings[cols] = listings[cols].swifter.apply(pd.to_datetime,errors='coerce', axis=1)

#Check
listings[cols].dtypes

# %% [markdown]
# **Formatting strings to numerics**

# %%
#List of columns to convert to numeric
cols = ['cleaning_fee','extra_people','price','host_response_rate','security_deposit']

#Remove $,commas, and % from cols in listings
listings[cols] = listings[cols].replace('[$%,]', '', regex=True)

#Convert columns in cols to numeric
listings[cols]= listings[cols].swifter.apply(pd.to_numeric, axis=1)

#Check
listings[cols].dtypes

# %%
#Convert zipcodes to numeric
listings.zipcode = listings.zipcode.swifter.apply(pd.to_numeric, axis=1)

# %% [markdown]
# # Remove this if not needed

# %%
#Present listings memory usage
#listings.memory_usage(deep=True).sort_values(ascending=False)

# %% [markdown]
# - 'int8' for small integers
# - 'category' for strings with few unique values
# - 'Sparse' if most values are 0 or NaN

# %%
# listings = listings.astype({ : 'int8',
#                              : 'category',
#                              : 'Sparse[int/str]'})

# int8: accommodates

# %% [markdown]
# #### Listings Outlier Removal for Price variable

# %%
#Airbnb price distributions
listings.price.plot(kind = 'hist', bins=55,  title='Price Distribution in San Francisco',
          legend = True, figsize=(10,6));

#Get axis object
ax = plt.gca()

#Format X axis
ax.get_xaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "$ {:,}".format(int(x))))

#Mute grid lines
ax.grid(b=False, which ='major', axis = 'x')

# %%
print(listings.shape)

# %%
#Calculate IQR of price
q25 = listings['price'].quantile(0.25)
q75= listings['price'].quantile(0.75)
iqr = q75 - q25

#Print percentiles
print('Percentiles: 25th={:.3f}, 75th={:.3f} \nIQR= {:.3f}'.format(q25, q75, iqr))

#Calculate outlier cutoffs
cut_off =1.5 * iqr
lower, upper = q25 - cut_off, q75 + iqr

#Identify outliers
outliers = [x for x in listings.price if x < lower or x > upper]
print("Number of outliers identified: {}".format(len(outliers)))

#Remove outliers
outliers_removed = [x for x in listings.price if x >= lower and x <= upper]
print('Non-outlier observations: {}'.format(len(outliers_removed)))

#Update df
listings = listings[listings.price.isin(outliers_removed)]
listings.shape

# %%
#Airbnb price distributions(outliers removed)
listings.price.plot(kind = 'hist', bins=40,  title='Price Distribution in San Francisco',
           figsize=(10,6));

#Capture mean and median of price
mean = listings.price.mean()
median = listings.price.median()

#Plot mean and median
plt.axvline(mean, color='r', linewidth=2, linestyle='--', label= str(round(mean,2)))
plt.axvline(median, color='green',linewidth=2, linestyle='--', label= str(median))

#Get axis object
ax = plt.gca()

#Format X axis
ax.get_xaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "${:,}".format(int(x))))

#Mute grid lines
plt.grid(b=False, which ='major', axis = 'x')

plt.legend(loc='upper right',frameon=True, fancybox=True)

# %%
# #Set path to write listings
# path = r'Data\02_Intermediate\12_24_2019_listings_cleaned.csv'

# #Write listings to path
# listings.to_csv(path)
